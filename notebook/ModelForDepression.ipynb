# %%
import pandas as pd

file_path = 'C:/Users/sachu/Desktop/Project/brfss2013/brfss2013.csv'
df = pd.read_csv(file_path, encoding='latin1')
# Out:
# C:\Users\sachu\AppData\Local\Temp\ipykernel_28112\3299477378.py:4: DtypeWarning: Columns (12,15,51,54,103,104,105,106,109,112,113,114,119,120,121,122,123,124,126,127,128,131,133,135,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,178,179,180,181,182,183,184,185,186,187,188,189,191,192,193,194,195,196,198,200,201,202,203,204,205,206,207,208,209,210,211,212,213,217,227,228,229,230,231,313) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='latin1')

# %%
print(df.head())
# Out:
#    Unnamed: 0  X_state    fmonth      idate    imonth  iday   iyear  \
# 0           1  Alabama   January  1092013.0   January   9.0  2013.0
# 1           2  Alabama   January  1192013.0   January  19.0  2013.0
# 2           3  Alabama   January  1192013.0   January  19.0  2013.0
# 3           4  Alabama   January  1112013.0   January  11.0  2013.0
# 4           5  Alabama  February  2062013.0  February   6.0  2013.0
#
#               dispcode         seqno         X_psu ctelenum pvtresd1 colghous  \
# 0  Completed interview  2.013001e+09  2.013001e+09      Yes      Yes      NaN
# 1  Completed interview  2.013001e+09  2.013001e+09      Yes      Yes      NaN
# 2  Completed interview  2.013001e+09  2.013001e+09      Yes      Yes      NaN
# 3  Completed interview  2.013001e+09  2.013001e+09      Yes      Yes      NaN
# 4  Completed interview  2.013001e+09  2.013001e+09      Yes      Yes      NaN
#
#   stateres              cellfon3 ladult  numadult  nummen  numwomen  \
# 0      Yes  Not a cellular phone    NaN       2.0     1.0       1.0
# 1      Yes  Not a cellular phone    NaN       2.0     1.0       1.0
# 2      Yes  Not a cellular phone    NaN       3.0     2.0       1.0
# 3      Yes  Not a cellular phone    NaN       2.0     1.0       1.0
# 4      Yes  Not a cellular phone    NaN       2.0     1.0       1.0
#
#      genhlth  physhlth  menthlth  poorhlth hlthpln1       persdoc2 medcost  \
# 0       Fair      30.0      29.0      30.0      Yes  Yes, only one      No
# 1       Good       0.0       0.0       NaN      Yes  Yes, only one      No
# 2       Good       3.0       2.0       0.0      Yes  Yes, only one      No
# 3  Very good       2.0       0.0       0.0      Yes  Yes, only one      No
# 4       Good      10.0       2.0       0.0      Yes  Yes, only one      No
#
#               checkup1  sleptim1 bphigh4 bpmeds bloodcho              cholchk  \
# 0     Within past year       NaN     Yes    Yes      Yes     Within past year
# 1     Within past year       6.0      No    NaN      Yes     Within past year
# 2     Within past year       9.0      No    NaN      Yes  5 or more years ago
# 3  Within past 2 years       8.0      No    NaN      Yes     Within past year
# 4  5 or more years ago       6.0     Yes     No      Yes  Within past 2 years
#
#   toldhi2 cvdinfr4 cvdcrhd4 cvdstrk3 asthma3 asthnow chcscncr chcocncr  \
# 0     Yes       No      NaN       No     Yes     Yes       No       No
# 1      No       No       No       No      No     NaN       No       No
# 2      No       No       No       No      No     NaN       No       No
# 3     Yes       No       No       No      No     NaN       No       No
# 4      No       No       No       No     Yes      No       No      Yes
#
#   chccopd1 havarth3 addepev2 chckidny diabete3 veteran3   marital  children  \
# 0      Yes      Yes      Yes      Yes       No       No  Divorced       0.0
# 1       No       No      Yes       No       No       No   Married       2.0
# 2       No      Yes      Yes       No       No       No   Married       0.0
# 3       No       No       No       No       No       No   Married       0.0
# 4       No       No       No       No       No       No   Married       0.0
#
#                                                educa             employ1  \
# 0         College 4 years or more (College graduate)             Retired
# 1  College 1 year to 3 years (Some college or tec...  Employed for wages
# 2         College 4 years or more (College graduate)  Employed for wages
# 3             Grade 12 or GED (High school graduate)             Retired
# 4         College 4 years or more (College graduate)             Retired
#
#              income2 weight2  height3 numhhol2  \
# 0  Less than $75,000   250.0    507.0      Yes
# 1    $75,000 or more   127.0    510.0       No
# 2    $75,000 or more   160.0    504.0       No
# 3  Less than $75,000   128.0    504.0       No
# 4  Less than $50,000   265.0    600.0       No
#
#                           numphon2 cpdemo1  cpdemo4 internet renthom1     sex  \
# 0  2 residential telephone numbers     Yes     10.0      Yes      Own  Female
# 1                              NaN     Yes     70.0      Yes      Own  Female
# 2                              NaN     Yes     70.0      Yes      Own  Female
# 3                              NaN     Yes     75.0      Yes      Own  Female
# 4                              NaN     Yes      0.0      Yes      Own    Male
#
#   pregnant qlactlm2 useequip blind decide diffwalk diffdres diffalon smoke100  \
# 0      NaN      Yes      Yes    No     No      Yes       No      Yes      Yes
# 1      NaN       No       No    No     No       No       No       No       No
# 2      NaN      Yes       No    No     No      Yes       No       No      Yes
# 3      NaN       No       No    No     No       No       No       No       No
# 4      NaN       No       No    No     No       No       No       No      Yes
#
#      smokday2 stopsmk2               lastsmk2     usenow3  alcday5  avedrnk2  \
# 0  Not at all      NaN       10 years or more  Not at all    201.0       2.0
# 1         NaN      NaN                    NaN  Not at all      0.0       NaN
# 2   Some days      Yes                    NaN  Not at all    220.0       4.0
# 3         NaN      NaN                    NaN  Not at all    208.0       2.0
# 4  Not at all      NaN  Within the past month  Not at all    210.0       2.0
#
#    drnk3ge5  maxdrnks  fruitju1  fruit1  fvbeans  fvgreen  fvorang  vegetab1  \
# 0       0.0       2.0     304.0   104.0    303.0    310.0    303.0       NaN
# 1       NaN       NaN     305.0   301.0    310.0    203.0    202.0     203.0
# 2      20.0      10.0     301.0   203.0    202.0    202.0    310.0     330.0
# 3       0.0       2.0     202.0   306.0    202.0    310.0    305.0     204.0
# 4       0.0       3.0       0.0   302.0    101.0    310.0    303.0     101.0
#
#   exerany2 exract11  exeroft1  exerhmm1  \
# 0       No      NaN       NaN       NaN
# 1      Yes  Walking     105.0      20.0
# 2       No      NaN       NaN       NaN
# 3      Yes  Walking     205.0      30.0
# 4       No      NaN       NaN       NaN
#
#                                             exract21  exeroft2  exerhmm2  \
# 0                                                NaN       NaN       NaN
# 1  Household Activities (vacuuming, dusting, home...     101.0      10.0
# 2                                                NaN       NaN       NaN
# 3                                  No other activity       NaN       NaN
# 4                                                NaN       NaN       NaN
#
#    strength lmtjoin3 arthdis2  arthsocl  joinpain seatbelt flushot6  \
# 0       0.0      Yes      Yes     A lot       7.0   Always       No
# 1       0.0      NaN      NaN       NaN       NaN   Always      Yes
# 2       0.0      Yes      Yes  A little       5.0   Always      Yes
# 3       0.0      NaN      NaN       NaN       NaN   Always       No
# 4       0.0      NaN      NaN       NaN       NaN   Always       No
#
#        flshtmy2                                     tetanus pneuvac3 hivtst6  \
# 0           NaN  No, did not receive any tetanus since 2005      Yes      No
# 1  October 2012                          Yes, received Tdap       No     Yes
# 2  January 2013                          Yes, received Tdap       No     Yes
# 3           NaN  No, did not receive any tetanus since 2005       No      No
# 4           NaN  No, did not receive any tetanus since 2005       No      No
#
#    hivtstd3               whrtst10 pdiabtst prediab1 diabage2 insulin  \
# 0       NaN                    NaN      Yes      Yes      NaN     NaN
# 1       NaN  Private doctor or HMO      Yes       No      NaN     NaN
# 2       NaN                At home      Yes       No      NaN     NaN
# 3       NaN                    NaN      Yes       No      NaN     NaN
# 4       NaN                    NaN       No       No      NaN     NaN
#
#    bldsugar  feetchk2 doctdiab  chkhemo3  feetchk eyeexam diabeye diabedu  \
# 0       NaN       NaN      NaN       NaN      NaN     NaN     NaN     NaN
# 1       NaN       NaN      NaN       NaN      NaN     NaN     NaN     NaN
# 2       NaN       NaN      NaN       NaN      NaN     NaN     NaN     NaN
# 3       NaN       NaN      NaN       NaN      NaN     NaN     NaN     NaN
# 4       NaN       NaN      NaN       NaN      NaN     NaN     NaN     NaN
#
#    painact2  qlmentl2  qlstres2  qlhlth2 medicare hlthcvrg  \
# 0       5.0      30.0      30.0      0.0      Yes      3 7
# 1       0.0       2.0       3.0     25.0       No        2
# 2      20.0       2.0       5.0      2.0       No        3
# 3       0.0       6.0       4.0     20.0       No        3
# 4       NaN       NaN       NaN      NaN      Yes      4 2
#
#                                    delaymed dlyother nocov121 lstcovrg  \
# 0            You didn't have transportation      NaN       No      NaN
# 1  No, I did not delay getting medical care      NaN       No      NaN
# 2                                       NaN      NaN       No      NaN
# 3  No, I did not delay getting medical care      NaN       No      NaN
# 4  No, I did not delay getting medical care      NaN       No      NaN
#
#    drvisits medscost            carercvd medbills  ssbsugar  ssbfrut2  \
# 0       5.0       No      Very satisfied       No     305.0     305.0
# 1       3.0       No      Very satisfied       No     203.0       0.0
# 2       6.0       No      Very satisfied       No     202.0     308.0
# 3       1.0       No  Somewhat satisfied       No     203.0     315.0
# 4       2.0       No      Very satisfied       No       NaN       NaN
#
#   wtchsalt  longwtch dradvise  asthmage asattack  aservist  asdrvist  \
# 0      Yes     408.0      Yes      56.0      Yes       0.0       0.0
# 1       No       NaN       No       NaN      NaN       NaN       NaN
# 2       No       NaN       No       NaN      NaN       NaN       NaN
# 3      Yes     405.0       No       NaN      NaN       NaN       NaN
# 4      NaN       NaN      NaN       NaN      NaN       NaN       NaN
#
#    asrchkup  asactlim                         asymptom asnoslep      asthmed3  \
# 0       3.0       NaN  Every day, but not all the time      NaN  1 to 14 days
# 1       NaN       NaN                              NaN      NaN           NaN
# 2       NaN       NaN                              NaN      NaN           NaN
# 3       NaN       NaN                              NaN      NaN           NaN
# 4       NaN       NaN                              NaN      NaN           NaN
#
#         asinhalr harehab1 strehab1 cvdasprn               aspunsaf rlivpain  \
# 0  5 to 14 times      NaN      NaN       No  Yes, stomach problems      NaN
# 1            NaN      NaN      NaN       No                     No      NaN
# 2            NaN      NaN      NaN       No                     No      NaN
# 3            NaN      NaN      NaN       No                     No      NaN
# 4            NaN      NaN      NaN      NaN                    NaN      NaN
#
#   rduchart rducstrk                                 arttoday arthwgt arthexer  \
# 0      NaN      NaN  I can do some things I would like to do     Yes      Yes
# 1      NaN      NaN                                      NaN     NaN      NaN
# 2      NaN      NaN  I can do some things I would like to do      No      Yes
# 3      NaN      NaN                                      NaN     NaN      NaN
# 4      NaN      NaN                                      NaN     NaN      NaN
#
#   arthedu                                           imfvplac hpvadvc2  \
# 0      No                                                NaN      NaN
# 1     NaN                                          Workplace      NaN
# 2      No  A doctor´s office or health maintenance organi...      NaN
# 3     NaN                                                NaN      NaN
# 4     NaN                                                NaN      NaN
#
#   hpvadsht hadmam              howlong profexam             lengexam hadpap2  \
# 0      NaN    Yes  Within past 2 years      Yes  Within past 2 years     Yes
# 1      NaN    Yes  Within past 3 years      Yes  Within past 3 years     Yes
# 2      NaN    Yes     Within past year      Yes     Within past year     Yes
# 3      NaN    Yes     Within past year      Yes  Within past 2 years     Yes
# 4      NaN    NaN                  NaN      NaN                  NaN     NaN
#
#               lastpap2 hadhyst2 bldstool             lstblds3 hadsigm3  \
# 0  5 or more years ago      Yes       No                  NaN      Yes
# 1  Within past 3 years       No       No                  NaN       No
# 2     Within past year      Yes      Yes  5 or more years ago      Yes
# 3  Within past 2 years       No      Yes  5 or more years ago      Yes
# 4                  NaN      NaN       No                  NaN      Yes
#
#       hadsgco1             lastsig3 pcpsaad2 pcpsadi1 pcpsare1 psatest1  \
# 0  Colonoscopy  Within past 2 years      NaN      NaN      NaN      NaN
# 1          NaN                  NaN      NaN      NaN      NaN      NaN
# 2  Colonoscopy  Within past 3 years      NaN      NaN      NaN      NaN
# 3  Colonoscopy  Within past 5 years      NaN      NaN      NaN      NaN
# 4  Colonoscopy  Within past 2 years      NaN      NaN      NaN      NaN
#
#   psatime pcpsars1 pcpsade1  pcdmdecn                   rrclass2 rrcognt2  \
# 0     NaN      NaN      NaN       NaN  Black or African American    Never
# 1     NaN      NaN      NaN       NaN                      White    Never
# 2     NaN      NaN      NaN       NaN                      White    Never
# 3     NaN      NaN      NaN       NaN                      White      NaN
# 4     NaN      NaN      NaN       NaN                        NaN      NaN
#
#                   rratwrk2                 rrhcare3 rrphysm2 rremtsm2  \
# 0                      NaN  The same as other races       No       No
# 1  The same as other races  The same as other races       No       No
# 2  The same as other races  The same as other races       No       No
# 3                      NaN  The same as other races       No       No
# 4                      NaN                      NaN      NaN      NaN
#
#    misnervs mishopls misrstls misdeprd miseffrt miswtles  misnowrk mistmnt  \
# 0      Some     Some     Some      NaN      All      NaN      30.0     Yes
# 1  A little      NaN      NaN      NaN      NaN      NaN       0.0      No
# 2       NaN      NaN      NaN      NaN      NaN      NaN       0.0      No
# 3  A little      NaN     Some      NaN      NaN      NaN       0.0      No
# 4       NaN      NaN      NaN      NaN      NaN      NaN       NaN     NaN
#
#          mistrhlp           misphlpf scntmony scntmeal          scntpaid  \
# 0  Agree strongly  Disagree slightly    Never    Never               NaN
# 1  Agree slightly  Disagree slightly    Never    Never  Paid by the hour
# 2  Agree strongly     Agree strongly    Never    Never  Paid by the hour
# 3  Agree strongly  Disagree slightly    Never    Never               NaN
# 4             NaN                NaN    Never    Never               NaN
#
#    scntwrk1                scntlpad  scntlwk1 scntvot1 rcsgendr rcsrltn2  \
# 0       NaN          Paid by salary       NaN      Yes      NaN      NaN
# 1      35.0                     NaN       NaN      Yes     Girl   Parent
# 2      40.0                     NaN       NaN      Yes      NaN      NaN
# 3       NaN          Paid by salary      60.0      Yes      NaN      NaN
# 4       NaN  Paid by the job / task      60.0      Yes      NaN      NaN
#
#   casthdx2 casthno2   emtsuprt        lsatisfy ctelnum1 cellfon2 cadult  \
# 0      NaN      NaN     Always  Very satisfied      NaN      NaN    NaN
# 1       No      NaN  Sometimes       Satisfied      NaN      NaN    NaN
# 2      NaN      NaN    Usually  Very satisfied      NaN      NaN    NaN
# 3      NaN      NaN    Usually  Very satisfied      NaN      NaN    NaN
# 4      NaN      NaN        NaN             NaN      NaN      NaN    NaN
#
#   pvtresd2 cclghous cstate landline  pctcell                 qstver  qstlang  \
# 0      NaN      NaN    NaN      NaN      NaN  Only Version Landline  English
# 1      NaN      NaN    NaN      NaN      NaN  Only Version Landline  English
# 2      NaN      NaN    NaN      NaN      NaN  Only Version Landline  English
# 3      NaN      NaN    NaN      NaN      NaN  Only Version Landline  English
# 4      NaN      NaN    NaN      NaN      NaN  Only Version Landline  English
#
#                                 mscode  X_ststr    X_strwt  X_rawrake  \
# 0  Inside a suburban county of the MSA  11081.0  40.197675        1.0
# 1  Inside a suburban county of the MSA  11081.0  40.197675        2.0
# 2  Inside a suburban county of the MSA  11081.0  40.197675        3.0
# 3  Inside a suburban county of the MSA  11081.0  40.197675        2.0
# 4  Inside a suburban county of the MSA  11082.0  60.319184        2.0
#
#     X_wt2rake            X_imprace  X_impnph  X_impeduc  X_impmrtl  X_imphome  \
# 0   40.197675  Black, Non-Hispanic       2.0        NaN        NaN        NaN
# 1   80.395350  White, Non-Hispanic       1.0        NaN        NaN        NaN
# 2  120.593025  White, Non-Hispanic       1.0        NaN        NaN        NaN
# 3   80.395350  White, Non-Hispanic       1.0        NaN        NaN        NaN
# 4  120.638368  White, Non-Hispanic       1.0        NaN        NaN        NaN
#
#                                            X_chispnc X_crace1  \
# 0                                                NaN      NaN
# 1  Child not of Hispanic, Latino/a, or Spanish or...    White
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
#          X_impcage            X_impcrac X_impcsex   X_cllcpwt  \
# 0              NaN                  NaN       NaN         NaN
# 1  10-14 Years old  White, non-Hispanic    Female  954.078239
# 2              NaN                  NaN       NaN         NaN
# 3              NaN                  NaN       NaN         NaN
# 4              NaN                  NaN       NaN         NaN
#
#            X_dualuse  X_dualcor   X_llcpwt2    X_llcpwt  \
# 0  No Dual Phone Use        NaN  331.493357  238.016092
# 1  No Dual Phone Use        NaN  662.986714  737.694204
# 2  No Dual Phone Use        NaN  994.480071  568.527386
# 3  No Dual Phone Use        NaN  662.986714  606.976365
# 4  No Dual Phone Use        NaN  994.853994  629.847064
#
#                 X_rfhlth                  X_hcvu651 X_rfhype5  \
# 0    Fair or Poor Health  Have health care coverage       Yes
# 1  Good or Better Health  Have health care coverage        No
# 2  Good or Better Health  Have health care coverage        No
# 3  Good or Better Health  Have health care coverage        No
# 4  Good or Better Health                        NaN       Yes
#
#                                           X_cholchk X_rfchol X_ltasth1  \
# 0           Had cholesterol checked in past 5 years      Yes       Yes
# 1           Had cholesterol checked in past 5 years       No        No
# 2  Did not have cholesterol checked in past 5 years       No        No
# 3           Had cholesterol checked in past 5 years      Yes        No
# 4           Had cholesterol checked in past 5 years       No       Yes
#
#   X_casthm1 X_asthms1                     X_drdxar1  \
# 0       Yes   Current      Diagnosed with arthritis
# 1        No     Never  Not diagnosed with arthritis
# 2        No     Never      Diagnosed with arthritis
# 3        No     Never  Not diagnosed with arthritis
# 4        No    Former  Not diagnosed with arthritis
#
#                     X_prace1                   X_mrace1  \
# 0  Black or African American  Black or African American
# 1                      White                      White
# 2                      White                      White
# 3                      White                      White
# 4                      White                      White
#
#                                       X_hispanc                    X_race  \
# 0  Not of Hispanic, Latino/a, or Spanish origin  Black only, non-Hispanic
# 1  Not of Hispanic, Latino/a, or Spanish origin  White only, non-Hispanic
# 2  Not of Hispanic, Latino/a, or Spanish origin  White only, non-Hispanic
# 3  Not of Hispanic, Latino/a, or Spanish origin  White only, non-Hispanic
# 4  Not of Hispanic, Latino/a, or Spanish origin  White only, non-Hispanic
#
#                X_raceg21                 X_racegr3             X_race_g1  \
# 0  Non-White or Hispanic  Black only, Non-Hispanic  Black - Non-Hispanic
# 1     Non-Hispanic White  White only, Non-Hispanic  White - Non-Hispanic
# 2     Non-Hispanic White  White only, Non-Hispanic  White - Non-Hispanic
# 3     Non-Hispanic White  White only, Non-Hispanic  White - Non-Hispanic
# 4     Non-Hispanic White  White only, Non-Hispanic  White - Non-Hispanic
#
#       X_ageg5yr        X_age65yr          X_age_g  htin4   htm4    wtkg3  \
# 0  Age 60 to 64     Age 18 to 64     Age 55 to 64   67.0  170.0  11340.0
# 1  Age 50 to 54     Age 18 to 64     Age 45 to 54   70.0  178.0   5761.0
# 2  Age 55 to 59     Age 18 to 64     Age 55 to 64   64.0  163.0   7257.0
# 3  Age 60 to 64     Age 18 to 64     Age 55 to 64   64.0  163.0   5806.0
# 4  Age 65 to 69  Age 65 or older  Age 65 or older   72.0  183.0  12020.0
#
#    X_bmi5      X_bmi5cat X_rfbmi5                  X_chldcnt  \
# 0  3916.0          Obese      Yes   No children in household
# 1  1822.0    Underweight       No  Two children in household
# 2  2746.0     Overweight      Yes   No children in household
# 3  2197.0  Normal weight       No   No children in household
# 4  3594.0          Obese      Yes   No children in household
#
#                                      X_educag                      X_incomg  \
# 0  Graduated from college or technical school               $50,000 or more
# 1        Attended college or technical school               $50,000 or more
# 2  Graduated from college or technical school               $50,000 or more
# 3                       Graduated high school               $50,000 or more
# 4  Graduated from college or technical school  $35,000 to less than $50,000
#
#                                X_smoker3 X_rfsmok3 drnkany5  drocdy3_  \
# 0                          Former smoker        No       No       3.0
# 1                           Never smoked        No      Yes       0.0
# 2  Current smoker - now smokes some days       Yes       No      67.0
# 3                           Never smoked        No       No      27.0
# 4                          Former smoker        No       No      33.0
#
#   X_rfbing5  X_drnkdy4  X_drnkmo4 X_rfdrhv4 X_rfdrmn4 X_rfdrwm4  ftjuda1_  \
# 0        No        7.0        2.0        No       NaN        No      13.0
# 1        No        0.0        0.0        No       NaN        No      17.0
# 2       Yes      267.0       80.0       Yes       NaN       Yes       3.0
# 3        No       53.0       16.0        No       NaN        No      29.0
# 4        No       67.0       20.0        No        No       NaN       0.0
#
#    frutda1_  beanday_  grenday_  orngday_  vegeda1_  \
# 0     400.0      10.0      33.0      10.0       NaN
# 1       3.0      33.0      43.0      29.0      43.0
# 2      43.0      29.0      29.0      33.0     100.0
# 3      20.0      29.0      33.0      17.0      57.0
# 4       7.0     100.0      33.0      10.0     100.0
#
#                     X_misfrtn                       X_misvegn  \
# 0  No missing fruit responses              1 missing response
# 1  No missing fruit responses  No missing vegetable responses
# 2  No missing fruit responses  No missing vegetable responses
# 3  No missing fruit responses  No missing vegetable responses
# 4  No missing fruit responses  No missing vegetable responses
#
#                             X_frtresp                               X_vegresp  \
# 0  Included - Missing Fruit Responses  Not Included - Missing Fruit Responses
# 1  Included - Missing Fruit Responses      Included - Missing Fruit Responses
# 2  Included - Missing Fruit Responses      Included - Missing Fruit Responses
# 3  Included - Missing Fruit Responses      Included - Missing Fruit Responses
# 4  Included - Missing Fruit Responses      Included - Missing Fruit Responses
#
#    X_frutsum  X_vegesum                                   X_frtlt1  \
# 0      413.0       53.0   Consumed fruit one or more times per day
# 1       20.0      148.0  Consumed fruit less than one time per day
# 2       46.0      191.0  Consumed fruit less than one time per day
# 3       49.0      136.0  Consumed fruit less than one time per day
# 4        7.0      243.0  Consumed fruit less than one time per day
#
#                                          X_veglt1  \
# 0  Consumed vegetables less than one time per day
# 1   Consumed vegetables one or more times per day
# 2   Consumed vegetables one or more times per day
# 3   Consumed vegetables one or more times per day
# 4   Consumed vegetables one or more times per day
#
#                                    X_frt16  \
# 0  Included - values are in accepted range
# 1  Included - values are in accepted range
# 2  Included - values are in accepted range
# 3  Included - values are in accepted range
# 4  Included - values are in accepted range
#
#                                    X_veg23  \
# 0  Included - values are in accepted range
# 1  Included - values are in accepted range
# 2  Included - values are in accepted range
# 3  Included - values are in accepted range
# 4  Included - values are in accepted range
#
#                                  X_fruitex  \
# 0  No missing values and in accepted range
# 1  No missing values and in accepted range
# 2  No missing values and in accepted range
# 3  No missing values and in accepted range
# 4  No missing values and in accepted range
#
#                                  X_vegetex  \
# 0             Missing vegetables responses
# 1  No missing values and in accepted range
# 2  No missing values and in accepted range
# 3  No missing values and in accepted range
# 4  No missing values and in accepted range
#
#                                           X_totinda  metvl11_  metvl21_  \
# 0  No physical activity or exercise in last 30 days       NaN       NaN
# 1                 Had physical activity or exercise      35.0      33.0
# 2  No physical activity or exercise in last 30 days       NaN       NaN
# 3                 Had physical activity or exercise      35.0       0.0
# 4  No physical activity or exercise in last 30 days       NaN       NaN
#
#    maxvo2_  fc60_  actin11_                                 actin21_  padur1_  \
# 0   2580.0  442.0       NaN                                      NaN      NaN
# 1   2950.0  506.0  Moderate                                 Moderate     20.0
# 2   2765.0  474.0       NaN                                      NaN      NaN
# 3   2432.0  417.0  Moderate  Not Moderate or Vigorous or No Activity     30.0
# 4   2370.0  406.0       NaN                                      NaN      NaN
#
#    padur2_  pafreq1_  pafreq2_  X_minac11  X_minac21  strfreq_  pamiss1_  \
# 0      NaN       NaN       NaN        NaN        NaN       0.0       0.0
# 1     10.0    5000.0    1000.0      100.0       10.0       0.0       0.0
# 2      NaN       NaN       NaN        NaN        NaN       0.0       0.0
# 3      NaN    1167.0       NaN       35.0        0.0       0.0       0.0
# 4      NaN       NaN       NaN        NaN        NaN       0.0       0.0
#
#    pamin11_  pamin21_  pa1min_  pavig11_  pavig21_ pa1vigm_  \
# 0       NaN       NaN      NaN       NaN       NaN      NaN
# 1     100.0      10.0    110.0       0.0       0.0      0.0
# 2       NaN       NaN      NaN       NaN       NaN      NaN
# 3      35.0       0.0     35.0       0.0       0.0      0.0
# 4       NaN       NaN      NaN       NaN       NaN      NaN
#
#                 X_pacat1                             X_paindx1      X_pa150r2  \
# 0               Inactive  Did not meet aerobic recommendations      0 minutes
# 1  Insufficiently active  Did not meet aerobic recommendations  1-149 minutes
# 2               Inactive  Did not meet aerobic recommendations      0 minutes
# 3  Insufficiently active  Did not meet aerobic recommendations  1-149 minutes
# 4               Inactive  Did not meet aerobic recommendations      0 minutes
#
#        X_pa300r2      X_pa30021  \
# 0      0 minutes  0-300 minutes
# 1  1-300 minutes  0-300 minutes
# 2      0 minutes  0-300 minutes
# 3  1-300 minutes  0-300 minutes
# 4      0 minutes  0-300 minutes
#
#                                            X_pastrng  \
# 0  Did not meet muscle strengthening recommendations
# 1  Did not meet muscle strengthening recommendations
# 2  Did not meet muscle strengthening recommendations
# 3  Did not meet muscle strengthening recommendations
# 4  Did not meet muscle strengthening recommendations
#
#                         X_parec1                     X_pastae1  \
# 0  Did not meet either guideline  Did not meet both guidelines
# 1  Did not meet either guideline  Did not meet both guidelines
# 2  Did not meet either guideline  Did not meet both guidelines
# 3  Did not meet either guideline  Did not meet both guidelines
# 4  Did not meet either guideline  Did not meet both guidelines
#
#                                            X_lmtact1  \
# 0  Told have arthritis and have limited usual act...
# 1                       Not told they have arthritis
# 2  Told have arthritis and have limited usual act...
# 3                       Not told they have arthritis
# 4                       Not told they have arthritis
#
#                                    X_lmtwrk1  \
# 0  Told have arthritis and have limited work
# 1               Not told they have arthritis
# 2  Told have arthritis and have limited work
# 3               Not told they have arthritis
# 4               Not told they have arthritis
#
#                                            X_lmtscl1  \
# 0  Told have arthritis and social activities limi...
# 1                       Not told they have arthritis
# 2  Told have arthritis and social activities limi...
# 3                       Not told they have arthritis
# 4                       Not told they have arthritis
#
#                                 X_rfseat2              X_rfseat3 X_flshot6  \
# 0  Always or almost always wear seat belt  Always wear seat belt       NaN
# 1  Always or almost always wear seat belt  Always wear seat belt       NaN
# 2  Always or almost always wear seat belt  Always wear seat belt       NaN
# 3  Always or almost always wear seat belt  Always wear seat belt       NaN
# 4  Always or almost always wear seat belt  Always wear seat belt        No
#
#   X_pneumo2 X_aidtst3  X_age80
# 0       NaN        No     60.0
# 1       NaN       Yes     50.0
# 2       NaN       Yes     55.0
# 3       NaN        No     64.0
# 4        No        No     66.0

# %%
df.shape
# Out:
# (491775, 331)

# %%
# Check and display columns with missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
print("Missing Values Count for Columns with Missing Values:")
print(missing_values)
# Out:
# Missing Values Count for Columns with Missing Values:
# fmonth            3
# idate             2
# imonth            3
# iday              3
# iyear             5
#               ...
# X_rfseat3     38941
# X_flshot6    343079
# X_pneumo2    349054
# X_aidtst3     54595
# X_age80          11
# Length: 329, dtype: int64

# %%
missing_values = df.isnull().sum()
print("Missing Values Count for Each Column:")
pd.set_option('display.max_rows', None)  # Display all rows
print(missing_values)
pd.reset_option('display.max_rows')  # Reset row display options
# Out:
# Missing Values Count for Each Column:
# Unnamed: 0         0
# X_state            0
# fmonth             3
# idate              2
# imonth             3
# iday               3
# iyear              5
# dispcode           5
# seqno              3
# X_psu              2
# ctelenum          41
# pvtresd1      131636
# colghous      491730
# stateres      131642
# cellfon3      135151
# ladult        491737
# numadult      131651
# nummen        131650
# numwomen      131650
# genhlth         1985
# physhlth       10957
# menthlth        8627
# poorhlth      243153
# hlthpln1        1904
# persdoc2        1801
# medcost         1221
# checkup1        6305
# sleptim1        7387
# bphigh4         1420
# bpmeds        293201
# bloodcho        9010
# cholchk        73178
# toldhi2        71662
# cvdinfr4        2587
# cvdcrhd4        4423
# cvdstrk3        1467
# asthma3         1559
# asthnow       426435
# chcscncr        1309
# chcocncr        1148
# chccopd1        2724
# havarth3        2970
# addepev2        2289
# chckidny        1721
# diabete3         832
# veteran3         746
# marital         3420
# children        2274
# educa           2274
# employ1         3386
# income2        71426
# weight2        20675
# height3         7623
# numhhol2      134365
# numphon2      475603
# cpdemo1       135081
# cpdemo4       227079
# internet        4926
# renthom1        8448
# sex                7
# pregnant      414790
# qlactlm2       11329
# useequip       10317
# blind          11079
# decide         12990
# diffwalk       12764
# diffdres       12122
# diffalon       13350
# smoke100       14920
# smokday2      276983
# stopsmk2      415421
# lastsmk2      354497
# usenow3        14018
# alcday5        19644
# avedrnk2      260590
# drnk3ge5      260444
# maxdrnks      264958
# fruitju1       36208
# fruit1         33798
# fvbeans        37492
# fvgreen        35157
# fvorang        36563
# vegetab1       38947
# exerany2       34029
# exract11      160948
# exeroft1      164165
# exerhmm1      168395
# exract21      166039
# exeroft2      278233
# exerhmm2      283651
# strength       39819
# lmtjoin3      338395
# arthdis2      341269
# arthsocl      338578
# joinpain      344065
# seatbelt       38935
# flushot6       40454
# flshtmy2      297165
# tetanus        83348
# pneuvac3       84502
# hivtst6        54593
# hivtstd3      387292
# whrtst10      362811
# pdiabtst      267197
# prediab1      257913
# diabage2      457669
# insulin       455380
# bldsugar      456007
# feetchk2      456497
# doctdiab      457059
# chkhemo3      458720
# feetchk       457125
# eyeexam       455970
# diabeye       455881
# diabedu       455487
# painact2      491287
# qlmentl2      491284
# qlstres2      491288
# qlhlth2       491310
# medicare      178791
# hlthcvrg      175883
# delaymed      144721
# dlyother      476507
# nocov121      182112
# lstcovrg      455021
# drvisits      154152
# medscost      142625
# carercvd      153216
# medbills      144297
# ssbsugar      388580
# ssbfrut2      388803
# wtchsalt      363748
# longwtch      421174
# dradvise      363788
# asthmage      490284
# asattack      490773
# aservist      491256
# asdrvist      491273
# asrchkup      490798
# asactlim      490849
# asymptom      490808
# asnoslep      491404
# asthmed3      490786
# asinhalr      490797
# harehab1      483230
# strehab1      485611
# cvdasprn      355557
# aspunsaf      403283
# rlivpain      445060
# rduchart      446035
# rducstrk      448602
# arttoday      470286
# arthwgt       470281
# arthexer      470399
# arthedu       470229
# imfvplac      468752
# hpvadvc2      478677
# hpvadsht      490572
# hadmam        461795
# howlong       467431
# profexam      461954
# lengexam      465346
# hadpap2       461962
# lastpap2      464182
# hadhyst2      462167
# bldstool      411977
# lstblds3      461248
# hadsigm3      411822
# hadsgco1      435281
# lastsig3      434482
# pcpsaad2      484775
# pcpsadi1      484819
# pcpsare1      484811
# psatest1      484898
# psatime       487957
# pcpsars1      487984
# pcpsade1      487913
# pcdmdecn      490517
# rrclass2      487870
# rrcognt2      487924
# rratwrk2      490238
# rrhcare3      488388
# rrphysm2      487832
# rremtsm2      487833
# misnervs      473638
# mishopls      484842
# misrstls      476060
# misdeprd      486871
# miseffrt      480331
# miswtles      487258
# misnowrk      455863
# mistmnt       455781
# mistrhlp      457246
# misphlpf      457333
# scntmony      429616
# scntmeal      425695
# scntpaid      459571
# scntwrk1      459413
# scntlpad      469779
# scntlwk1      470493
# scntvot1      426461
# rcsgendr      421687
# rcsrltn2      422041
# casthdx2      425967
# casthno2      482731
# emtsuprt      480154
# lsatisfy      480104
# ctelnum1      360173
# cellfon2      360144
# cadult        360144
# pvtresd2      360149
# cclghous      490581
# cstate        360148
# landline      360154
# pctcell       466929
# qstver            11
# qstlang          378
# mscode        136643
# X_ststr            4
# X_strwt            6
# X_rawrake          6
# X_wt2rake          6
# X_imprace          9
# X_impnph      131639
# X_impeduc     491772
# X_impmrtl     491772
# X_imphome     491772
# X_chispnc     419789
# X_crace1      420235
# X_impcage     414828
# X_impcrac     414827
# X_impcsex     414826
# X_cllcpwt     419607
# X_dualuse         11
# X_dualcor     431031
# X_llcpwt2          6
# X_llcpwt           7
# X_rfhlth        1989
# X_hcvu651     166598
# X_rfhype5       1427
# X_cholchk      14286
# X_rfchol       71664
# X_ltasth1       1567
# X_casthm1       3430
# X_asthms1       3429
# X_drdxar1       2976
# X_prace1        8376
# X_mrace1        8375
# X_hispanc       5439
# X_race          8570
# X_raceg21       8570
# X_racegr3       8572
# X_race_g1       8570
# X_ageg5yr       4730
# X_age65yr       4732
# X_age_g           12
# htin4           9510
# htm4            7643
# wtkg3          20685
# X_bmi5         26727
# X_bmi5cat      26727
# X_rfbmi5       26729
# X_chldcnt       2280
# X_educag        2280
# X_incomg       71428
# X_smoker3      15333
# X_rfsmok3      15335
# drnkany5       19647
# drocdy3_       19646
# X_rfbing5      23731
# X_drnkdy4      23881
# X_drnkmo4      23882
# X_rfdrhv4      23883
# X_rfdrmn4     301354
# X_rfdrwm4     214307
# ftjuda1_       36211
# frutda1_       33800
# beanday_       37495
# grenday_       35159
# orngday_       36564
# vegeda1_       38948
# X_misfrtn         11
# X_misvegn          9
# X_frtresp         12
# X_vegresp         10
# X_frutsum      28702
# X_vegesum      30165
# X_frtlt1       28703
# X_veglt1       30164
# X_frt16           10
# X_veg23           12
# X_fruitex         10
# X_vegetex         12
# X_totinda      34034
# metvl11_      175069
# metvl21_      183999
# maxvo2_         4729
# fc60_           4730
# actin11_      177754
# actin21_      186563
# padur1_       168396
# padur2_       283652
# pafreq1_      164169
# pafreq2_      278234
# X_minac11     170039
# X_minac21     174656
# strfreq_       39824
# pamiss1_       34032
# pamin11_      186263
# pamin21_      193752
# pa1min_       167961
# pavig11_      181421
# pavig21_      189965
# pa1vigm_      166302
# X_pacat1       76878
# X_paindx1      67571
# X_pa150r2      67570
# X_pa300r2      76878
# X_pa30021      76877
# X_pastrng      39825
# X_parec1       71486
# X_pastae1      71489
# X_lmtact1      14748
# X_lmtwrk1      17622
# X_lmtscl1      14931
# X_rfseat2      38943
# X_rfseat3      38941
# X_flshot6     343079
# X_pneumo2     349054
# X_aidtst3      54595
# X_age80           11
# dtype: int64

# %%
# Define a threshold for the maximum number of missing values
threshold = 250000

# Get the columns with missing values counts
missing_values = df.isnull().sum()

# Find columns with more than the specified threshold
columns_to_drop = missing_values[missing_values > threshold].index

# Drop the columns from the dataset
df = df.drop(columns=columns_to_drop)

# %%
# Now, data will contain only columns with fewer than 250,000 missing values.

df
# Out:
#         Unnamed: 0      X_state    fmonth      idate    imonth  iday   iyear  \
# 0                1      Alabama   January  1092013.0   January   9.0  2013.0
# 1                2      Alabama   January  1192013.0   January  19.0  2013.0
# 2                3      Alabama   January  1192013.0   January  19.0  2013.0
# 3                4      Alabama   January  1112013.0   January  11.0  2013.0
# 4                5      Alabama  February  2062013.0  February   6.0  2013.0
# ...            ...          ...       ...        ...       ...   ...     ...
# 491770      491771  Puerto Rico      June  6212013.0      June  21.0  2013.0
# 491771      491772  Puerto Rico      June  6222013.0      June  22.0  2013.0
# 491772      491773  Puerto Rico      July  8062013.0    August   6.0  2013.0
# 491773      491774  Puerto Rico      July  8052013.0    August   5.0  2013.0
# 491774      491775  Puerto Rico      July  7282013.0      July  28.0  2013.0
#
#                              dispcode         seqno         X_psu ctelenum  \
# 0                 Completed interview  2.013001e+09  2.013001e+09      Yes
# 1                 Completed interview  2.013001e+09  2.013001e+09      Yes
# 2                 Completed interview  2.013001e+09  2.013001e+09      Yes
# 3                 Completed interview  2.013001e+09  2.013001e+09      Yes
# 4                 Completed interview  2.013001e+09  2.013001e+09      Yes
# ...                               ...           ...           ...      ...
# 491770            Completed interview  2.013005e+09  2.013005e+09      Yes
# 491771            Completed interview  2.013005e+09  2.013005e+09      Yes
# 491772  Partially completed interview  2.013005e+09  2.013005e+09      Yes
# 491773            Completed interview  2.013005e+09  2.013005e+09      Yes
# 491774            Completed interview  2.013005e+09  2.013005e+09      Yes
#
#        pvtresd1 stateres              cellfon3  numadult  nummen  numwomen  \
# 0           Yes      Yes  Not a cellular phone       2.0     1.0       1.0
# 1           Yes      Yes  Not a cellular phone       2.0     1.0       1.0
# 2           Yes      Yes  Not a cellular phone       3.0     2.0       1.0
# 3           Yes      Yes  Not a cellular phone       2.0     1.0       1.0
# 4           Yes      Yes  Not a cellular phone       2.0     1.0       1.0
# ...         ...      ...                   ...       ...     ...       ...
# 491770      NaN      NaN                   NaN       NaN     NaN       NaN
# 491771      NaN      NaN                   NaN       NaN     NaN       NaN
# 491772      NaN      NaN                   NaN       NaN     NaN       NaN
# 491773      NaN      NaN                   NaN       NaN     NaN       NaN
# 491774      NaN      NaN                   NaN       NaN     NaN       NaN
#
#           genhlth  physhlth  menthlth  poorhlth hlthpln1       persdoc2  \
# 0            Fair      30.0      29.0      30.0      Yes  Yes, only one
# 1            Good       0.0       0.0       NaN      Yes  Yes, only one
# 2            Good       3.0       2.0       0.0      Yes  Yes, only one
# 3       Very good       2.0       0.0       0.0      Yes  Yes, only one
# 4            Good      10.0       2.0       0.0      Yes  Yes, only one
# ...           ...       ...       ...       ...      ...            ...
# 491770       Fair      14.0      15.0       0.0      Yes  More than one
# 491771       Good       0.0       0.0       NaN      Yes  Yes, only one
# 491772       Fair      15.0      20.0       0.0      Yes  More than one
# 491773  Very good       0.0       0.0       NaN      Yes  Yes, only one
# 491774       Good      30.0       NaN      30.0      Yes  More than one
#
#        medcost             checkup1  sleptim1 bphigh4 bloodcho  \
# 0           No     Within past year       NaN     Yes      Yes
# 1           No     Within past year       6.0      No      Yes
# 2           No     Within past year       9.0      No      Yes
# 3           No  Within past 2 years       8.0      No      Yes
# 4           No  5 or more years ago       6.0     Yes      Yes
# ...        ...                  ...       ...     ...      ...
# 491770      No     Within past year       6.0     Yes      Yes
# 491771      No     Within past year       7.0      No      Yes
# 491772     Yes     Within past year       7.0      No      Yes
# 491773      No     Within past year       8.0      No       No
# 491774      No     Within past year       7.0      No      Yes
#
#                     cholchk toldhi2 cvdinfr4 cvdcrhd4 cvdstrk3 asthma3  \
# 0          Within past year     Yes       No      NaN       No     Yes
# 1          Within past year      No       No       No       No      No
# 2       5 or more years ago      No       No       No       No      No
# 3          Within past year     Yes       No       No       No      No
# 4       Within past 2 years      No       No       No       No     Yes
# ...                     ...     ...      ...      ...      ...     ...
# 491770     Within past year     Yes      Yes      Yes       No      No
# 491771     Within past year     Yes       No       No       No      No
# 491772     Within past year      No       No       No       No     Yes
# 491773                  NaN     NaN       No       No       No      No
# 491774     Within past year     Yes       No       No       No     Yes
#
#        chcscncr chcocncr chccopd1 havarth3 addepev2 chckidny diabete3  \
# 0            No       No      Yes      Yes      Yes      Yes       No
# 1            No       No       No       No      Yes       No       No
# 2            No       No       No      Yes      Yes       No       No
# 3            No       No       No       No       No       No       No
# 4            No      Yes       No       No       No       No       No
# ...         ...      ...      ...      ...      ...      ...      ...
# 491770       No       No       No      Yes      Yes       No      Yes
# 491771       No       No       No      Yes       No       No      Yes
# 491772       No       No       No       No       No       No       No
# 491773       No       No       No       No       No       No       No
# 491774       No       No       No       No       No       No       No
#
#        veteran3                          marital  children  \
# 0            No                         Divorced       0.0
# 1            No                          Married       2.0
# 2            No                          Married       0.0
# 3            No                          Married       0.0
# 4            No                          Married       0.0
# ...         ...                              ...       ...
# 491770       No                         Divorced       0.0
# 491771       No                    Never married       0.0
# 491772       No  A member of an unmarried couple       3.0
# 491773       No                        Separated       2.0
# 491774       No                    Never married       0.0
#
#                                                     educa             employ1  \
# 0              College 4 years or more (College graduate)             Retired
# 1       College 1 year to 3 years (Some college or tec...  Employed for wages
# 2              College 4 years or more (College graduate)  Employed for wages
# 3                  Grade 12 or GED (High school graduate)             Retired
# 4              College 4 years or more (College graduate)             Retired
# ...                                                   ...                 ...
# 491770             Grade 12 or GED (High school graduate)         A homemaker
# 491771              Grades 9 though 11 (Some high school)      Unable to work
# 491772  College 1 year to 3 years (Some college or tec...  Employed for wages
# 491773  College 1 year to 3 years (Some college or tec...         A homemaker
# 491774         College 4 years or more (College graduate)  Employed for wages
#
#                   income2 weight2  height3 numhhol2 cpdemo1  cpdemo4 internet  \
# 0       Less than $75,000   250.0    507.0      Yes     Yes     10.0      Yes
# 1         $75,000 or more   127.0    510.0       No     Yes     70.0      Yes
# 2         $75,000 or more   160.0    504.0       No     Yes     70.0      Yes
# 3       Less than $75,000   128.0    504.0       No     Yes     75.0      Yes
# 4       Less than $50,000   265.0    600.0       No     Yes      0.0      Yes
# ...                   ...     ...      ...      ...     ...      ...      ...
# 491770  Less than $15,000   138.0    500.0      NaN     NaN      NaN       No
# 491771                NaN   182.0    503.0      NaN     NaN      NaN       No
# 491772  Less than $15,000   157.0    505.0      NaN     NaN      NaN       No
# 491773  Less than $10,000   130.0    504.0      NaN     NaN      NaN      Yes
# 491774  Less than $15,000   175.0    504.0      NaN     NaN      NaN      Yes
#
#                  renthom1     sex qlactlm2 useequip blind decide diffwalk  \
# 0                     Own  Female      Yes      Yes    No     No      Yes
# 1                     Own  Female       No       No    No     No       No
# 2                     Own  Female      Yes       No    No     No      Yes
# 3                     Own  Female       No       No    No     No       No
# 4                     Own    Male       No       No    No     No       No
# ...                   ...     ...      ...      ...   ...    ...      ...
# 491770                Own  Female      Yes       No    No    Yes      Yes
# 491771                Own    Male       No       No   Yes     No      Yes
# 491772                Own  Female       No       No    No     No       No
# 491773  Other arrangement  Female       No       No    No     No       No
# 491774                Own    Male       No       No    No     No      Yes
#
#        diffdres diffalon smoke100     usenow3  alcday5  fruitju1  fruit1  \
# 0            No      Yes      Yes  Not at all    201.0     304.0   104.0
# 1            No       No       No  Not at all      0.0     305.0   301.0
# 2            No       No      Yes  Not at all    220.0     301.0   203.0
# 3            No       No       No  Not at all    208.0     202.0   306.0
# 4            No       No      Yes  Not at all    210.0       0.0   302.0
# ...         ...      ...      ...         ...      ...       ...     ...
# 491770      Yes      Yes       No  Not at all      0.0     101.0   302.0
# 491771       No       No       No  Not at all      0.0       0.0   302.0
# 491772       No       No       No  Not at all      0.0     102.0   103.0
# 491773       No       No       No  Not at all      0.0     310.0   205.0
# 491774       No       No       No  Not at all      0.0       0.0   203.0
#
#         fvbeans  fvgreen  fvorang  vegetab1 exerany2 exract11  exeroft1  \
# 0         303.0    310.0    303.0       NaN       No      NaN       NaN
# 1         310.0    203.0    202.0     203.0      Yes  Walking     105.0
# 2         202.0    202.0    310.0     330.0       No      NaN       NaN
# 3         202.0    310.0    305.0     204.0      Yes  Walking     205.0
# 4         101.0    310.0    303.0     101.0       No      NaN       NaN
# ...         ...      ...      ...       ...      ...      ...       ...
# 491770    101.0    101.0    202.0     101.0       No      NaN       NaN
# 491771    101.0      0.0      0.0       NaN       No      NaN       NaN
# 491772      0.0    304.0    203.0     205.0      Yes  Walking     204.0
# 491773    101.0    203.0      0.0     203.0      Yes  Walking     104.0
# 491774    207.0    202.0    201.0     207.0      Yes  Walking     103.0
#
#         exerhmm1                                           exract21  strength  \
# 0            NaN                                                NaN       0.0
# 1           20.0  Household Activities (vacuuming, dusting, home...       0.0
# 2            NaN                                                NaN       0.0
# 3           30.0                                  No other activity       0.0
# 4            NaN                                                NaN       0.0
# ...          ...                                                ...       ...
# 491770       NaN                                                NaN       0.0
# 491771       NaN                                                NaN       0.0
# 491772     100.0                                  No other activity       0.0
# 491773     100.0                                  No other activity       0.0
# 491774      30.0  Yard work (cutting/gathering wood, trimming he...     103.0
#
#        seatbelt flushot6                                            tetanus  \
# 0        Always       No         No, did not receive any tetanus since 2005
# 1        Always      Yes                                 Yes, received Tdap
# 2        Always      Yes                                 Yes, received Tdap
# 3        Always       No         No, did not receive any tetanus since 2005
# 4        Always       No         No, did not receive any tetanus since 2005
# ...         ...      ...                                                ...
# 491770   Always       No         No, did not receive any tetanus since 2005
# 491771   Always       No         No, did not receive any tetanus since 2005
# 491772   Always       No  Yes, received tetanus shot but not sure what type
# 491773   Always       No         No, did not receive any tetanus since 2005
# 491774   Always       No         No, did not receive any tetanus since 2005
#
#        pneuvac3 hivtst6 medicare hlthcvrg  \
# 0           Yes      No      Yes      3 7
# 1            No     Yes       No        2
# 2            No     Yes       No        3
# 3            No      No       No        3
# 4            No      No      Yes      4 2
# ...         ...     ...      ...      ...
# 491770       No      No       No        4
# 491771       No      No       No        4
# 491772      NaN     Yes       No        4
# 491773       No     Yes       No        4
# 491774       No     Yes       No        3
#
#                                                  delaymed nocov121  drvisits  \
# 0                          You didn't have transportation       No       5.0
# 1                No, I did not delay getting medical care       No       3.0
# 2                                                     NaN       No       6.0
# 3                No, I did not delay getting medical care       No       1.0
# 4                No, I did not delay getting medical care       No       2.0
# ...                                                   ...      ...       ...
# 491770           No, I did not delay getting medical care       No       3.0
# 491771           No, I did not delay getting medical care       No       NaN
# 491772           No, I did not delay getting medical care       No      15.0
# 491773           No, I did not delay getting medical care       No       0.0
# 491774  The (clinic/doctor's) office wasn't open when ...      Yes       3.0
#
#        medscost            carercvd medbills                   qstver  \
# 0            No      Very satisfied       No    Only Version Landline
# 1            No      Very satisfied       No    Only Version Landline
# 2            No      Very satisfied       No    Only Version Landline
# 3            No  Somewhat satisfied       No    Only Version Landline
# 4            No      Very satisfied       No    Only Version Landline
# ...         ...                 ...      ...                      ...
# 491770      Yes  Somewhat satisfied       No  Only Version Cell Phone
# 491771       No  Somewhat satisfied       No  Only Version Cell Phone
# 491772       No  Somewhat satisfied       No  Only Version Cell Phone
# 491773       No      Very satisfied       No  Only Version Cell Phone
# 491774       No  Somewhat satisfied       No  Only Version Cell Phone
#
#         qstlang                               mscode   X_ststr     X_strwt  \
# 0       English  Inside a suburban county of the MSA   11081.0   40.197675
# 1       English  Inside a suburban county of the MSA   11081.0   40.197675
# 2       English  Inside a suburban county of the MSA   11081.0   40.197675
# 3       English  Inside a suburban county of the MSA   11081.0   40.197675
# 4       English  Inside a suburban county of the MSA   11082.0   60.319184
# ...         ...                                  ...       ...         ...
# 491770  Spanish                                  NaN  722019.0  309.857400
# 491771  Spanish                                  NaN  722019.0  309.857400
# 491772  Spanish                                  NaN  722019.0  309.857400
# 491773  Spanish                                  NaN  722019.0  309.857400
# 491774  Spanish                                  NaN  722019.0  309.857400
#
#         X_rawrake   X_wt2rake            X_imprace  X_impnph  \
# 0             1.0   40.197675  Black, Non-Hispanic       2.0
# 1             2.0   80.395350  White, Non-Hispanic       1.0
# 2             3.0  120.593025  White, Non-Hispanic       1.0
# 3             2.0   80.395350  White, Non-Hispanic       1.0
# 4             2.0  120.638368  White, Non-Hispanic       1.0
# ...           ...         ...                  ...       ...
# 491770        1.0  309.857400             Hispanic       NaN
# 491771        1.0  309.857400             Hispanic       NaN
# 491772        1.0  309.857400             Hispanic       NaN
# 491773        1.0  309.857400             Hispanic       NaN
# 491774        1.0  309.857400             Hispanic       NaN
#
#                 X_dualuse   X_llcpwt2     X_llcpwt               X_rfhlth  \
# 0       No Dual Phone Use  331.493357   238.016092    Fair or Poor Health
# 1       No Dual Phone Use  662.986714   737.694204  Good or Better Health
# 2       No Dual Phone Use  994.480071   568.527386  Good or Better Health
# 3       No Dual Phone Use  662.986714   606.976365  Good or Better Health
# 4       No Dual Phone Use  994.853994   629.847064  Good or Better Health
# ...                   ...         ...          ...                    ...
# 491770  No Dual Phone Use  800.887347   682.993059    Fair or Poor Health
# 491771  No Dual Phone Use  800.887347   544.547576  Good or Better Health
# 491772  No Dual Phone Use  800.887347   349.930515    Fair or Poor Health
# 491773  No Dual Phone Use  800.887347  1385.438160  Good or Better Health
# 491774  No Dual Phone Use    8.000000          NaN                    NaN
#
#                         X_hcvu651 X_rfhype5  \
# 0       Have health care coverage       Yes
# 1       Have health care coverage        No
# 2       Have health care coverage        No
# 3       Have health care coverage        No
# 4                             NaN       Yes
# ...                           ...       ...
# 491770  Have health care coverage       Yes
# 491771  Have health care coverage        No
# 491772  Have health care coverage        No
# 491773  Have health care coverage        No
# 491774                        NaN       NaN
#
#                                                X_cholchk X_rfchol X_ltasth1  \
# 0                Had cholesterol checked in past 5 years      Yes       Yes
# 1                Had cholesterol checked in past 5 years       No        No
# 2       Did not have cholesterol checked in past 5 years       No        No
# 3                Had cholesterol checked in past 5 years      Yes        No
# 4                Had cholesterol checked in past 5 years       No       Yes
# ...                                                  ...      ...       ...
# 491770           Had cholesterol checked in past 5 years      Yes        No
# 491771           Had cholesterol checked in past 5 years      Yes        No
# 491772           Had cholesterol checked in past 5 years       No       Yes
# 491773                Have never had cholesterol checked      NaN        No
# 491774                                               NaN      NaN       NaN
#
#        X_casthm1 X_asthms1                     X_drdxar1  \
# 0            Yes   Current      Diagnosed with arthritis
# 1             No     Never  Not diagnosed with arthritis
# 2             No     Never      Diagnosed with arthritis
# 3             No     Never  Not diagnosed with arthritis
# 4             No    Former  Not diagnosed with arthritis
# ...          ...       ...                           ...
# 491770        No     Never      Diagnosed with arthritis
# 491771        No     Never      Diagnosed with arthritis
# 491772       Yes   Current  Not diagnosed with arthritis
# 491773        No     Never  Not diagnosed with arthritis
# 491774       NaN       NaN                           NaN
#
#                          X_prace1                   X_mrace1  \
# 0       Black or African American  Black or African American
# 1                           White                      White
# 2                           White                      White
# 3                           White                      White
# 4                           White                      White
# ...                           ...                        ...
# 491770                      White                      White
# 491771                        NaN                        NaN
# 491772                 Other race            Other race only
# 491773                      White                      White
# 491774                        NaN                        NaN
#
#                                            X_hispanc  \
# 0       Not of Hispanic, Latino/a, or Spanish origin
# 1       Not of Hispanic, Latino/a, or Spanish origin
# 2       Not of Hispanic, Latino/a, or Spanish origin
# 3       Not of Hispanic, Latino/a, or Spanish origin
# 4       Not of Hispanic, Latino/a, or Spanish origin
# ...                                              ...
# 491770         Hispanic, Latino/a, or Spanish origin
# 491771         Hispanic, Latino/a, or Spanish origin
# 491772         Hispanic, Latino/a, or Spanish origin
# 491773         Hispanic, Latino/a, or Spanish origin
# 491774                                           NaN
#
#                           X_race              X_raceg21  \
# 0       Black only, non-Hispanic  Non-White or Hispanic
# 1       White only, non-Hispanic     Non-Hispanic White
# 2       White only, non-Hispanic     Non-Hispanic White
# 3       White only, non-Hispanic     Non-Hispanic White
# 4       White only, non-Hispanic     Non-Hispanic White
# ...                          ...                    ...
# 491770                  Hispanic  Non-White or Hispanic
# 491771                  Hispanic  Non-White or Hispanic
# 491772                  Hispanic  Non-White or Hispanic
# 491773                  Hispanic  Non-White or Hispanic
# 491774                       NaN                    NaN
#
#                        X_racegr3             X_race_g1     X_ageg5yr  \
# 0       Black only, Non-Hispanic  Black - Non-Hispanic  Age 60 to 64
# 1       White only, Non-Hispanic  White - Non-Hispanic  Age 50 to 54
# 2       White only, Non-Hispanic  White - Non-Hispanic  Age 55 to 59
# 3       White only, Non-Hispanic  White - Non-Hispanic  Age 60 to 64
# 4       White only, Non-Hispanic  White - Non-Hispanic  Age 65 to 69
# ...                          ...                   ...           ...
# 491770                  Hispanic              Hispanic  Age 55 to 59
# 491771                  Hispanic              Hispanic  Age 60 to 64
# 491772                  Hispanic              Hispanic  Age 35 to 39
# 491773                  Hispanic              Hispanic  Age 30 to 34
# 491774                       NaN                   NaN           NaN
#
#               X_age65yr          X_age_g  htin4   htm4    wtkg3  X_bmi5  \
# 0          Age 18 to 64     Age 55 to 64   67.0  170.0  11340.0  3916.0
# 1          Age 18 to 64     Age 45 to 54   70.0  178.0   5761.0  1822.0
# 2          Age 18 to 64     Age 55 to 64   64.0  163.0   7257.0  2746.0
# 3          Age 18 to 64     Age 55 to 64   64.0  163.0   5806.0  2197.0
# 4       Age 65 or older  Age 65 or older   72.0  183.0  12020.0  3594.0
# ...                 ...              ...    ...    ...      ...     ...
# 491770     Age 18 to 64     Age 55 to 64   60.0  152.0   6260.0  2695.0
# 491771     Age 18 to 64     Age 55 to 64   63.0  160.0   8255.0  3224.0
# 491772     Age 18 to 64     Age 35 to 44   65.0  165.0   7121.0  2613.0
# 491773     Age 18 to 64     Age 25 to 34   64.0  163.0   5897.0  2231.0
# 491774              NaN              NaN    NaN    NaN      NaN     NaN
#
#             X_bmi5cat X_rfbmi5                    X_chldcnt  \
# 0               Obese      Yes     No children in household
# 1         Underweight       No    Two children in household
# 2          Overweight      Yes     No children in household
# 3       Normal weight       No     No children in household
# 4               Obese      Yes     No children in household
# ...               ...      ...                          ...
# 491770     Overweight      Yes     No children in household
# 491771          Obese      Yes     No children in household
# 491772     Overweight      Yes  Three children in household
# 491773  Normal weight       No    Two children in household
# 491774            NaN      NaN                          NaN
#
#                                           X_educag  \
# 0       Graduated from college or technical school
# 1             Attended college or technical school
# 2       Graduated from college or technical school
# 3                            Graduated high school
# 4       Graduated from college or technical school
# ...                                            ...
# 491770                       Graduated high school
# 491771                Did not graduate high school
# 491772        Attended college or technical school
# 491773        Attended college or technical school
# 491774                                         NaN
#
#                             X_incomg                              X_smoker3  \
# 0                    $50,000 or more                          Former smoker
# 1                    $50,000 or more                           Never smoked
# 2                    $50,000 or more  Current smoker - now smokes some days
# 3                    $50,000 or more                           Never smoked
# 4       $35,000 to less than $50,000                          Former smoker
# ...                              ...                                    ...
# 491770             Less than $15,000                           Never smoked
# 491771                           NaN                           Never smoked
# 491772             Less than $15,000                           Never smoked
# 491773             Less than $15,000                           Never smoked
# 491774                           NaN                                    NaN
#
#        X_rfsmok3 drnkany5  drocdy3_ X_rfbing5  X_drnkdy4  X_drnkmo4 X_rfdrhv4  \
# 0             No       No       3.0        No        7.0        2.0        No
# 1             No      Yes       0.0        No        0.0        0.0        No
# 2            Yes       No      67.0       Yes      267.0       80.0       Yes
# 3             No       No      27.0        No       53.0       16.0        No
# 4             No       No      33.0        No       67.0       20.0        No
# ...          ...      ...       ...       ...        ...        ...       ...
# 491770        No      Yes       0.0        No        0.0        0.0        No
# 491771        No      Yes       0.0        No        0.0        0.0        No
# 491772        No      Yes       0.0        No        0.0        0.0        No
# 491773        No      Yes       0.0        No        0.0        0.0        No
# 491774       NaN      NaN       NaN       NaN        NaN        NaN       NaN
#
#        X_rfdrwm4  ftjuda1_  frutda1_  beanday_  grenday_  orngday_  vegeda1_  \
# 0             No      13.0     400.0      10.0      33.0      10.0       NaN
# 1             No      17.0       3.0      33.0      43.0      29.0      43.0
# 2            Yes       3.0      43.0      29.0      29.0      33.0     100.0
# 3             No      29.0      20.0      29.0      33.0      17.0      57.0
# 4            NaN       0.0       7.0     100.0      33.0      10.0     100.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 491770        No     100.0       7.0     100.0     100.0      29.0     100.0
# 491771       NaN       0.0       7.0     100.0       0.0       0.0       NaN
# 491772        No     200.0     300.0       0.0      13.0      43.0      71.0
# 491773        No      33.0      71.0     100.0      43.0       0.0      43.0
# 491774       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#                          X_misfrtn                       X_misvegn  \
# 0       No missing fruit responses              1 missing response
# 1       No missing fruit responses  No missing vegetable responses
# 2       No missing fruit responses  No missing vegetable responses
# 3       No missing fruit responses  No missing vegetable responses
# 4       No missing fruit responses  No missing vegetable responses
# ...                            ...                             ...
# 491770  No missing fruit responses  No missing vegetable responses
# 491771  No missing fruit responses              1 missing response
# 491772  No missing fruit responses  No missing vegetable responses
# 491773  No missing fruit responses  No missing vegetable responses
# 491774                         NaN                             NaN
#
#                                  X_frtresp  \
# 0       Included - Missing Fruit Responses
# 1       Included - Missing Fruit Responses
# 2       Included - Missing Fruit Responses
# 3       Included - Missing Fruit Responses
# 4       Included - Missing Fruit Responses
# ...                                    ...
# 491770  Included - Missing Fruit Responses
# 491771  Included - Missing Fruit Responses
# 491772  Included - Missing Fruit Responses
# 491773  Included - Missing Fruit Responses
# 491774                                 NaN
#
#                                      X_vegresp  X_frutsum  X_vegesum  \
# 0       Not Included - Missing Fruit Responses      413.0       53.0
# 1           Included - Missing Fruit Responses       20.0      148.0
# 2           Included - Missing Fruit Responses       46.0      191.0
# 3           Included - Missing Fruit Responses       49.0      136.0
# 4           Included - Missing Fruit Responses        7.0      243.0
# ...                                        ...        ...        ...
# 491770      Included - Missing Fruit Responses      107.0      329.0
# 491771  Not Included - Missing Fruit Responses        7.0      100.0
# 491772      Included - Missing Fruit Responses      500.0      127.0
# 491773      Included - Missing Fruit Responses      104.0      186.0
# 491774                                     NaN        NaN        NaN
#
#                                          X_frtlt1  \
# 0        Consumed fruit one or more times per day
# 1       Consumed fruit less than one time per day
# 2       Consumed fruit less than one time per day
# 3       Consumed fruit less than one time per day
# 4       Consumed fruit less than one time per day
# ...                                           ...
# 491770   Consumed fruit one or more times per day
# 491771  Consumed fruit less than one time per day
# 491772   Consumed fruit one or more times per day
# 491773   Consumed fruit one or more times per day
# 491774                                        NaN
#
#                                               X_veglt1  \
# 0       Consumed vegetables less than one time per day
# 1        Consumed vegetables one or more times per day
# 2        Consumed vegetables one or more times per day
# 3        Consumed vegetables one or more times per day
# 4        Consumed vegetables one or more times per day
# ...                                                ...
# 491770   Consumed vegetables one or more times per day
# 491771   Consumed vegetables one or more times per day
# 491772   Consumed vegetables one or more times per day
# 491773   Consumed vegetables one or more times per day
# 491774                                             NaN
#
#                                         X_frt16  \
# 0       Included - values are in accepted range
# 1       Included - values are in accepted range
# 2       Included - values are in accepted range
# 3       Included - values are in accepted range
# 4       Included - values are in accepted range
# ...                                         ...
# 491770  Included - values are in accepted range
# 491771  Included - values are in accepted range
# 491772  Included - values are in accepted range
# 491773  Included - values are in accepted range
# 491774                                      NaN
#
#                                         X_veg23  \
# 0       Included - values are in accepted range
# 1       Included - values are in accepted range
# 2       Included - values are in accepted range
# 3       Included - values are in accepted range
# 4       Included - values are in accepted range
# ...                                         ...
# 491770  Included - values are in accepted range
# 491771  Included - values are in accepted range
# 491772  Included - values are in accepted range
# 491773  Included - values are in accepted range
# 491774                                      NaN
#
#                                       X_fruitex  \
# 0       No missing values and in accepted range
# 1       No missing values and in accepted range
# 2       No missing values and in accepted range
# 3       No missing values and in accepted range
# 4       No missing values and in accepted range
# ...                                         ...
# 491770  No missing values and in accepted range
# 491771  No missing values and in accepted range
# 491772  No missing values and in accepted range
# 491773  No missing values and in accepted range
# 491774                                      NaN
#
#                                       X_vegetex  \
# 0                  Missing vegetables responses
# 1       No missing values and in accepted range
# 2       No missing values and in accepted range
# 3       No missing values and in accepted range
# 4       No missing values and in accepted range
# ...                                         ...
# 491770  No missing values and in accepted range
# 491771             Missing vegetables responses
# 491772  No missing values and in accepted range
# 491773  No missing values and in accepted range
# 491774                                      NaN
#
#                                                X_totinda  metvl11_  metvl21_  \
# 0       No physical activity or exercise in last 30 days       NaN       NaN
# 1                      Had physical activity or exercise      35.0      33.0
# 2       No physical activity or exercise in last 30 days       NaN       NaN
# 3                      Had physical activity or exercise      35.0       0.0
# 4       No physical activity or exercise in last 30 days       NaN       NaN
# ...                                                  ...       ...       ...
# 491770  No physical activity or exercise in last 30 days       NaN       NaN
# 491771  No physical activity or exercise in last 30 days       NaN       NaN
# 491772                 Had physical activity or exercise      35.0       0.0
# 491773                 Had physical activity or exercise      35.0       0.0
# 491774                                               NaN       NaN       NaN
#
#         maxvo2_  fc60_  actin11_                                 actin21_  \
# 0        2580.0  442.0       NaN                                      NaN
# 1        2950.0  506.0  Moderate                                 Moderate
# 2        2765.0  474.0       NaN                                      NaN
# 3        2432.0  417.0  Moderate  Not Moderate or Vigorous or No Activity
# 4        2370.0  406.0       NaN                                      NaN
# ...         ...    ...       ...                                      ...
# 491770   2654.0  455.0       NaN                                      NaN
# 491771   2590.0  444.0       NaN                                      NaN
# 491772   3431.0  588.0  Moderate  Not Moderate or Vigorous or No Activity
# 491773   3690.0  633.0  Moderate  Not Moderate or Vigorous or No Activity
# 491774      NaN    NaN       NaN                                      NaN
#
#         padur1_  pafreq1_  X_minac11  X_minac21  strfreq_  pamiss1_  pamin11_  \
# 0           NaN       NaN        NaN        NaN       0.0       0.0       NaN
# 1          20.0    5000.0      100.0       10.0       0.0       0.0     100.0
# 2           NaN       NaN        NaN        NaN       0.0       0.0       NaN
# 3          30.0    1167.0       35.0        0.0       0.0       0.0      35.0
# 4           NaN       NaN        NaN        NaN       0.0       0.0       NaN
# ...         ...       ...        ...        ...       ...       ...       ...
# 491770      NaN       NaN        NaN        NaN       0.0       0.0       NaN
# 491771      NaN       NaN        NaN        NaN       0.0       0.0       NaN
# 491772     60.0     933.0       56.0        0.0       0.0       0.0      56.0
# 491773     60.0    4000.0      240.0        0.0       0.0       0.0     240.0
# 491774      NaN       NaN        NaN        NaN       NaN       NaN       NaN
#
#         pamin21_  pa1min_  pavig11_  pavig21_ pa1vigm_               X_pacat1  \
# 0            NaN      NaN       NaN       NaN      NaN               Inactive
# 1           10.0    110.0       0.0       0.0      0.0  Insufficiently active
# 2            NaN      NaN       NaN       NaN      NaN               Inactive
# 3            0.0     35.0       0.0       0.0      0.0  Insufficiently active
# 4            NaN      NaN       NaN       NaN      NaN               Inactive
# ...          ...      ...       ...       ...      ...                    ...
# 491770       NaN      NaN       NaN       NaN      NaN               Inactive
# 491771       NaN      NaN       NaN       NaN      NaN               Inactive
# 491772       0.0     56.0       0.0       0.0      0.0  Insufficiently active
# 491773       0.0    240.0       0.0       0.0      0.0                 Active
# 491774       NaN      NaN       NaN       NaN      NaN                    NaN
#
#                                    X_paindx1      X_pa150r2      X_pa300r2  \
# 0       Did not meet aerobic recommendations      0 minutes      0 minutes
# 1       Did not meet aerobic recommendations  1-149 minutes  1-300 minutes
# 2       Did not meet aerobic recommendations      0 minutes      0 minutes
# 3       Did not meet aerobic recommendations  1-149 minutes  1-300 minutes
# 4       Did not meet aerobic recommendations      0 minutes      0 minutes
# ...                                      ...            ...            ...
# 491770  Did not meet aerobic recommendations      0 minutes      0 minutes
# 491771  Did not meet aerobic recommendations      0 minutes      0 minutes
# 491772  Did not meet aerobic recommendations  1-149 minutes  1-300 minutes
# 491773           Met aerobic recommendations   150+ minutes  1-300 minutes
# 491774                                   NaN            NaN            NaN
#
#             X_pa30021                                          X_pastrng  \
# 0       0-300 minutes  Did not meet muscle strengthening recommendations
# 1       0-300 minutes  Did not meet muscle strengthening recommendations
# 2       0-300 minutes  Did not meet muscle strengthening recommendations
# 3       0-300 minutes  Did not meet muscle strengthening recommendations
# 4       0-300 minutes  Did not meet muscle strengthening recommendations
# ...               ...                                                ...
# 491770  0-300 minutes  Did not meet muscle strengthening recommendations
# 491771  0-300 minutes  Did not meet muscle strengthening recommendations
# 491772  0-300 minutes  Did not meet muscle strengthening recommendations
# 491773  0-300 minutes  Did not meet muscle strengthening recommendations
# 491774            NaN                                                NaN
#
#                              X_parec1                     X_pastae1  \
# 0       Did not meet either guideline  Did not meet both guidelines
# 1       Did not meet either guideline  Did not meet both guidelines
# 2       Did not meet either guideline  Did not meet both guidelines
# 3       Did not meet either guideline  Did not meet both guidelines
# 4       Did not meet either guideline  Did not meet both guidelines
# ...                               ...                           ...
# 491770  Did not meet either guideline  Did not meet both guidelines
# 491771  Did not meet either guideline  Did not meet both guidelines
# 491772  Did not meet either guideline  Did not meet both guidelines
# 491773    Met aerobic guidelines only  Did not meet both guidelines
# 491774                            NaN                           NaN
#
#                                                 X_lmtact1  \
# 0       Told have arthritis and have limited usual act...
# 1                            Not told they have arthritis
# 2       Told have arthritis and have limited usual act...
# 3                            Not told they have arthritis
# 4                            Not told they have arthritis
# ...                                                   ...
# 491770  Told have arthritis and no limited usual activ...
# 491771  Told have arthritis and have limited usual act...
# 491772                       Not told they have arthritis
# 491773                       Not told they have arthritis
# 491774                                                NaN
#
#                                         X_lmtwrk1  \
# 0       Told have arthritis and have limited work
# 1                    Not told they have arthritis
# 2       Told have arthritis and have limited work
# 3                    Not told they have arthritis
# 4                    Not told they have arthritis
# ...                                           ...
# 491770    Told have arthritis and no limited work
# 491771  Told have arthritis and have limited work
# 491772               Not told they have arthritis
# 491773               Not told they have arthritis
# 491774                                        NaN
#
#                                                 X_lmtscl1  \
# 0       Told have arthritis and social activities limi...
# 1                            Not told they have arthritis
# 2       Told have arthritis and social activities limi...
# 3                            Not told they have arthritis
# 4                            Not told they have arthritis
# ...                                                   ...
# 491770  Told have arthritis and social activities limi...
# 491771  Told have arthritis and social activities not ...
# 491772                       Not told they have arthritis
# 491773                       Not told they have arthritis
# 491774                                                NaN
#
#                                      X_rfseat2              X_rfseat3  \
# 0       Always or almost always wear seat belt  Always wear seat belt
# 1       Always or almost always wear seat belt  Always wear seat belt
# 2       Always or almost always wear seat belt  Always wear seat belt
# 3       Always or almost always wear seat belt  Always wear seat belt
# 4       Always or almost always wear seat belt  Always wear seat belt
# ...                                        ...                    ...
# 491770  Always or almost always wear seat belt  Always wear seat belt
# 491771  Always or almost always wear seat belt  Always wear seat belt
# 491772  Always or almost always wear seat belt  Always wear seat belt
# 491773  Always or almost always wear seat belt  Always wear seat belt
# 491774                                     NaN                    NaN
#
#        X_aidtst3  X_age80
# 0             No     60.0
# 1            Yes     50.0
# 2            Yes     55.0
# 3             No     64.0
# 4             No     66.0
# ...          ...      ...
# 491770        No     58.0
# 491771        No     62.0
# 491772       Yes     37.0
# 491773       Yes     30.0
# 491774       NaN      NaN
#
# [491775 rows x 191 columns]

# %%
missing_values = df.isnull().sum()
print("Missing Values Count for Each Column:")
pd.set_option('display.max_rows', None)  # Display all rows
print(missing_values)
pd.reset_option('display.max_rows')  # Reset row display options
# Out:
# Missing Values Count for Each Column:
# Unnamed: 0         0
# X_state            0
# fmonth             3
# idate              2
# imonth             3
# iday               3
# iyear              5
# dispcode           5
# seqno              3
# X_psu              2
# ctelenum          41
# pvtresd1      131636
# stateres      131642
# cellfon3      135151
# numadult      131651
# nummen        131650
# numwomen      131650
# genhlth         1985
# physhlth       10957
# menthlth        8627
# poorhlth      243153
# hlthpln1        1904
# persdoc2        1801
# medcost         1221
# checkup1        6305
# sleptim1        7387
# bphigh4         1420
# bloodcho        9010
# cholchk        73178
# toldhi2        71662
# cvdinfr4        2587
# cvdcrhd4        4423
# cvdstrk3        1467
# asthma3         1559
# chcscncr        1309
# chcocncr        1148
# chccopd1        2724
# havarth3        2970
# addepev2        2289
# chckidny        1721
# diabete3         832
# veteran3         746
# marital         3420
# children        2274
# educa           2274
# employ1         3386
# income2        71426
# weight2        20675
# height3         7623
# numhhol2      134365
# cpdemo1       135081
# cpdemo4       227079
# internet        4926
# renthom1        8448
# sex                7
# qlactlm2       11329
# useequip       10317
# blind          11079
# decide         12990
# diffwalk       12764
# diffdres       12122
# diffalon       13350
# smoke100       14920
# usenow3        14018
# alcday5        19644
# fruitju1       36208
# fruit1         33798
# fvbeans        37492
# fvgreen        35157
# fvorang        36563
# vegetab1       38947
# exerany2       34029
# exract11      160948
# exeroft1      164165
# exerhmm1      168395
# exract21      166039
# strength       39819
# seatbelt       38935
# flushot6       40454
# tetanus        83348
# pneuvac3       84502
# hivtst6        54593
# medicare      178791
# hlthcvrg      175883
# delaymed      144721
# nocov121      182112
# drvisits      154152
# medscost      142625
# carercvd      153216
# medbills      144297
# qstver            11
# qstlang          378
# mscode        136643
# X_ststr            4
# X_strwt            6
# X_rawrake          6
# X_wt2rake          6
# X_imprace          9
# X_impnph      131639
# X_dualuse         11
# X_llcpwt2          6
# X_llcpwt           7
# X_rfhlth        1989
# X_hcvu651     166598
# X_rfhype5       1427
# X_cholchk      14286
# X_rfchol       71664
# X_ltasth1       1567
# X_casthm1       3430
# X_asthms1       3429
# X_drdxar1       2976
# X_prace1        8376
# X_mrace1        8375
# X_hispanc       5439
# X_race          8570
# X_raceg21       8570
# X_racegr3       8572
# X_race_g1       8570
# X_ageg5yr       4730
# X_age65yr       4732
# X_age_g           12
# htin4           9510
# htm4            7643
# wtkg3          20685
# X_bmi5         26727
# X_bmi5cat      26727
# X_rfbmi5       26729
# X_chldcnt       2280
# X_educag        2280
# X_incomg       71428
# X_smoker3      15333
# X_rfsmok3      15335
# drnkany5       19647
# drocdy3_       19646
# X_rfbing5      23731
# X_drnkdy4      23881
# X_drnkmo4      23882
# X_rfdrhv4      23883
# X_rfdrwm4     214307
# ftjuda1_       36211
# frutda1_       33800
# beanday_       37495
# grenday_       35159
# orngday_       36564
# vegeda1_       38948
# X_misfrtn         11
# X_misvegn          9
# X_frtresp         12
# X_vegresp         10
# X_frutsum      28702
# X_vegesum      30165
# X_frtlt1       28703
# X_veglt1       30164
# X_frt16           10
# X_veg23           12
# X_fruitex         10
# X_vegetex         12
# X_totinda      34034
# metvl11_      175069
# metvl21_      183999
# maxvo2_         4729
# fc60_           4730
# actin11_      177754
# actin21_      186563
# padur1_       168396
# pafreq1_      164169
# X_minac11     170039
# X_minac21     174656
# strfreq_       39824
# pamiss1_       34032
# pamin11_      186263
# pamin21_      193752
# pa1min_       167961
# pavig11_      181421
# pavig21_      189965
# pa1vigm_      166302
# X_pacat1       76878
# X_paindx1      67571
# X_pa150r2      67570
# X_pa300r2      76878
# X_pa30021      76877
# X_pastrng      39825
# X_parec1       71486
# X_pastae1      71489
# X_lmtact1      14748
# X_lmtwrk1      17622
# X_lmtscl1      14931
# X_rfseat2      38943
# X_rfseat3      38941
# X_aidtst3      54595
# X_age80           11
# dtype: int64

# %%
"""Data correction for age group less than 30"""

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
missing_values_subset = df[df['X_age80'] < 30].isnull().sum()
missing_values_subset= missing_values_subset[missing_values_subset > 0]
print("Missing Values Count for Columns with Missing Values:")
print(missing_values_subset)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Out:
# Missing Values Count for Columns with Missing Values:
# ctelenum         4
# pvtresd1     36080
# stateres     36081
# cellfon3     36190
# numadult     36082
# nummen       36082
# numwomen     36082
# genhlth        115
# physhlth       618
# menthlth       627
# poorhlth     21929
# hlthpln1       666
# persdoc2       320
# medcost        113
# checkup1      1043
# sleptim1       395
# bphigh4        138
# bloodcho      3036
# cholchk      26945
# toldhi2      26461
# cvdinfr4       128
# cvdcrhd4       105
# cvdstrk3        82
# asthma3        174
# chcscncr        73
# chcocncr        73
# chccopd1       220
# havarth3       218
# addepev2       268
# chckidny        86
# diabete3        84
# veteran3        79
# marital        373
# children       214
# educa          182
# employ1        428
# income2       8757
# weight2       1508
# height3        878
# numhhol2     36176
# cpdemo1      36189
# cpdemo4      39052
# internet       515
# renthom1       944
# qlactlm2      1324
# useequip      1345
# blind         1381
# decide        1561
# diffwalk      1538
# diffdres      1572
# diffalon      1662
# smoke100      1829
# usenow3       1795
# alcday5       2395
# fruitju1      4732
# fruit1        4377
# fvbeans       4612
# fvgreen       4619
# fvorang       4768
# vegetab1      4984
# exerany2      4817
# exract11     13523
# exeroft1     13778
# exerhmm1     14007
# exract21     14151
# strength      5521
# seatbelt      5456
# flushot6      5792
# tetanus      10383
# pneuvac3     16372
# hivtst6       6604
# medicare     25293
# hlthcvrg     24322
# delaymed     17142
# nocov121     25286
# drvisits     17707
# medscost     16950
# carercvd     18426
# medbills     17396
# qstver           1
# qstlang        127
# mscode       36633
# X_strwt          1
# X_rawrake        1
# X_wt2rake        1
# X_imprace        1
# X_impnph     36081
# X_dualuse        2
# X_llcpwt2        2
# X_llcpwt         1
# X_rfhlth       117
# X_hcvu651      681
# X_rfhype5      141
# X_cholchk     3662
# X_rfchol     26464
# X_ltasth1      177
# X_casthm1      500
# X_asthms1      500
# X_drdxar1      221
# X_prace1      1045
# X_mrace1      1044
# X_hispanc      668
# X_race         903
# X_raceg21      902
# X_racegr3      902
# X_race_g1      902
# X_ageg5yr       15
# X_age65yr       15
# X_age_g          2
# htin4         1287
# htm4           881
# wtkg3         1512
# X_bmi5        3485
# X_bmi5cat     3485
# X_rfbmi5      3486
# X_chldcnt      216
# X_educag       184
# X_incomg      8759
# X_smoker3     1852
# X_rfsmok3     1852
# drnkany5      2395
# drocdy3_      2394
# X_rfbing5     2919
# X_drnkdy4     3083
# X_drnkmo4     3083
# X_rfdrhv4     3083
# X_rfdrwm4    25801
# ftjuda1_      4734
# frutda1_      4378
# beanday_      4613
# grenday_      4620
# orngday_      4769
# vegeda1_      4984
# X_misfrtn        2
# X_misvegn        2
# X_frtresp        2
# X_vegresp        2
# X_frutsum     3930
# X_vegesum     4151
# X_frtlt1      3931
# X_veglt1      4150
# X_frt16          1
# X_veg23          3
# X_fruitex        2
# X_vegetex        1
# X_totinda     4817
# metvl11_     15105
# metvl21_     16166
# maxvo2_         14
# fc60_           13
# actin11_     15109
# actin21_     16171
# padur1_      14005
# pafreq1_     13779
# X_minac11    14119
# X_minac21    15304
# strfreq_      5521
# pamiss1_      4816
# pamin11_     15678
# pamin21_     17123
# pa1min_      13961
# pavig11_     15130
# pavig21_     16276
# pa1vigm_     13705
# X_pacat1      9370
# X_paindx1     8378
# X_pa150r2     8378
# X_pa300r2     9371
# X_pa30021     9369
# X_pastrng     5522
# X_parec1      8815
# X_pastae1     8817
# X_lmtact1      479
# X_lmtwrk1      500
# X_lmtscl1      481
# X_rfseat2     5458
# X_rfseat3     5456
# X_aidtst3     6603
# dtype: int64

# %%
# Calculate missing values for columns in the subset of rows
missing_values_subset1 = df[(df['X_age80'] > 30) & (df['X_age80'] < 50)].isnull().sum()

# Filter for columns with missing values
missing_values_subset1 = missing_values_subset1[missing_values_subset1 > 0]

# Print the count of missing values for selected columns
print("Missing Values Count for Columns with Missing Values:")
print(missing_values_subset1)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Out:
# Missing Values Count for Columns with Missing Values:
# ctelenum        12
# pvtresd1     47781
# stateres     47782
# cellfon3     48507
# numadult     47786
# nummen       47786
# numwomen     47786
# genhlth        341
# physhlth      1414
# menthlth      1404
# poorhlth     56093
# hlthpln1       269
# persdoc2       345
# medcost        258
# checkup1      1375
# sleptim1      1018
# bphigh4        217
# bloodcho      2332
# cholchk      22749
# toldhi2      22460
# cvdinfr4       380
# cvdcrhd4       389
# cvdstrk3       235
# asthma3        260
# chcscncr       187
# chcocncr       234
# chccopd1       395
# havarth3       569
# addepev2       506
# chckidny       250
# diabete3       193
# veteran3       179
# marital        784
# children       791
# educa          533
# employ1        783
# income2      10634
# weight2       5078
# height3       2102
# numhhol2     48271
# cpdemo1      48403
# cpdemo4      60581
# internet      1207
# renthom1      1998
# qlactlm2      2757
# useequip      2717
# blind         2787
# decide        3162
# diffwalk      3081
# diffdres      3142
# diffalon      3372
# smoke100      3701
# usenow3       3598
# alcday5       4851
# fruitju1      8694
# fruit1        8204
# fvbeans       8619
# fvgreen       8467
# fvorang       8779
# vegetab1      9198
# exerany2      8856
# exract11     35292
# exeroft1     35792
# exerhmm1     36386
# exract21     36508
# strength     10092
# seatbelt     10173
# flushot6     10578
# tetanus      20445
# pneuvac3     26888
# hivtst6      13564
# medicare     46940
# hlthcvrg     46341
# delaymed     34465
# nocov121     48375
# drvisits     35478
# medscost     33945
# carercvd     37325
# medbills     34261
# qstlang        132
# mscode       48953
# X_impnph     47781
# X_rfhlth       341
# X_hcvu651     1247
# X_rfhype5      217
# X_cholchk     3193
# X_rfchol     22460
# X_ltasth1      260
# X_casthm1      721
# X_asthms1      721
# X_drdxar1      569
# X_prace1      2483
# X_mrace1      2483
# X_hispanc     1267
# X_race        1933
# X_raceg21     1933
# X_racegr3     1933
# X_race_g1     1933
# X_ageg5yr     1012
# X_age65yr     1012
# htin4         2982
# htm4          2109
# wtkg3         5079
# X_bmi5        7193
# X_bmi5cat     7193
# X_rfbmi5      7193
# X_chldcnt      791
# X_educag       533
# X_incomg     10634
# X_smoker3     3787
# X_rfsmok3     3787
# drnkany5      4851
# drocdy3_      4851
# X_rfbing5     5902
# X_drnkdy4     5914
# X_drnkmo4     5914
# X_rfdrhv4     5914
# X_rfdrwm4    53818
# ftjuda1_      8694
# frutda1_      8204
# beanday_      8619
# grenday_      8467
# orngday_      8779
# vegeda1_      9198
# X_frutsum     7398
# X_vegesum     7752
# X_frtlt1      7398
# X_veglt1      7752
# X_totinda     8856
# metvl11_     38605
# metvl21_     40610
# maxvo2_       1012
# fc60_         1012
# actin11_     39188
# actin21_     41188
# padur1_      36386
# pafreq1_     35792
# X_minac11    36617
# X_minac21    38224
# strfreq_     10092
# pamiss1_      8856
# pamin11_     40415
# pamin21_     42572
# pa1min_      36699
# pavig11_     39314
# pavig21_     41509
# pa1vigm_     36295
# X_pacat1     18491
# X_paindx1    16425
# X_pa150r2    16425
# X_pa300r2    18491
# X_pa30021    18491
# X_pastrng    10092
# X_parec1     17161
# X_pastae1    17161
# X_lmtact1     2063
# X_lmtwrk1     2228
# X_lmtscl1     2088
# X_rfseat2    10173
# X_rfseat3    10173
# X_aidtst3    13564
# dtype: int64

# %%
# Calculate missing values for columns in the subset of rows
missing_values_subset2 = df[(df['X_age80'] > 50)].isnull().sum()

# Filter for columns with missing values
missing_values_subset2 = missing_values_subset2[missing_values_subset2 > 0]

# Print the count of missing values for selected columns
print("Missing Values Count for Columns with Missing Values:")
print(missing_values_subset2)
# Out:
# Missing Values Count for Columns with Missing Values:
# ctelenum         18
# pvtresd1      41374
# stateres      41378
# cellfon3      43960
# numadult      41382
# nummen        41383
# numwomen      41383
# genhlth        1479
# physhlth       8712
# menthlth       6379
# poorhlth     157761
# hlthpln1        921
# persdoc2       1079
# medcost         807
# checkup1       3699
# sleptim1       5804
# bphigh4        1029
# bloodcho       3305
# cholchk       20388
# toldhi2       19735
# cvdinfr4       2018
# cvdcrhd4       3865
# cvdstrk3       1122
# asthma3        1084
# chcscncr       1007
# chcocncr        795
# chccopd1       2045
# havarth3       2102
# addepev2       1461
# chckidny       1348
# diabete3        532
# veteran3        460
# marital        2129
# children       1165
# educa          1480
# employ1        2041
# income2       50436
# weight2       13375
# height3        4329
# numhhol2      43437
# cpdemo1       43977
# cpdemo4      119006
# internet       3018
# renthom1       5186
# qlactlm2       6836
# useequip       5851
# blind          6484
# decide         7797
# diffwalk       7668
# diffdres       6940
# diffalon       7822
# smoke100       8831
# usenow3        8083
# alcday5       11659
# fruitju1      21530
# fruit1        20001
# fvbeans       22990
# fvgreen       20818
# fvorang       21724
# vegetab1      23397
# exerany2      19062
# exract11     107439
# exeroft1     109825
# exerhmm1     113137
# exract21     110501
# strength      22752
# seatbelt      21853
# flushot6      22557
# tetanus       49746
# pneuvac3      37837
# hivtst6       32516
# medicare     100192
# hlthcvrg      98961
# delaymed      88451
# nocov121     101906
# drvisits      96129
# medscost      87129
# carercvd      92454
# medbills      87989
# qstlang          93
# mscode        44471
# X_impnph      41374
# X_rfhlth       1479
# X_hcvu651    164583
# X_rfhype5      1029
# X_cholchk      6951
# X_rfchol      19735
# X_ltasth1      1084
# X_casthm1      2112
# X_asthms1      2112
# X_drdxar1      2102
# X_prace1       4523
# X_mrace1       4523
# X_hispanc      3316
# X_race         5448
# X_raceg21      5448
# X_racegr3      5448
# X_race_g1      5448
# X_ageg5yr      3659
# X_age65yr      3659
# htin4          4808
# htm4           4336
# wtkg3         13377
# X_bmi5        15005
# X_bmi5cat     15005
# X_rfbmi5      15005
# X_chldcnt      1165
# X_educag       1480
# X_incomg      50436
# X_smoker3      9122
# X_rfsmok3      9122
# drnkany5      11659
# drocdy3_      11659
# X_rfbing5     14011
# X_drnkdy4     13998
# X_drnkmo4     13998
# X_rfdrhv4     13998
# X_rfdrwm4    127574
# ftjuda1_      21530
# frutda1_      20001
# beanday_      22990
# grenday_      20818
# orngday_      21724
# vegeda1_      23397
# X_frutsum     16288
# X_vegesum     17109
# X_frtlt1      16288
# X_veglt1      17109
# X_totinda     19062
# metvl11_     116251
# metvl21_     121801
# maxvo2_        3659
# fc60_          3659
# actin11_     118326
# actin21_     123761
# padur1_      113137
# pafreq1_     109825
# X_minac11    114400
# X_minac21    115993
# strfreq_      22752
# pamiss1_      19062
# pamin11_     124844
# pamin21_     128404
# pa1min_      112460
# pavig11_     121832
# pavig21_     126681
# pa1vigm_     111538
# X_pacat1      46459
# X_paindx1     40512
# X_pa150r2     40512
# X_pa300r2     46459
# X_pa30021     46459
# X_pastrng     22752
# X_parec1      43153
# X_pastae1     43153
# X_lmtact1     11878
# X_lmtwrk1     14537
# X_lmtscl1     12036
# X_rfseat2     21853
# X_rfseat3     21853
# X_aidtst3     32516
# dtype: int64

# %%
"""dropping columns having high chance of biasing or no contribution for the model"""

columns_to_drop =  ['ctelenum'
		,'pvtresd1'
		,'stateres'
		,'cellfon3'
		,'numadult'
		,'nummen'
		,'numwomen'
		,'numhhol2'
		,'cpdemo1'
		,'exerany2'
		,'exract11'
		,'exract21'
		,'qstver'
		,'qstlang'
		,'mscode'
		,'X_hcvu651'
        ,'X_imprace'
        ]

df = df.drop(columns=columns_to_drop)

# %%
"""converting text column to numerial for convinence"""

replacement_mapping = {
    'Within past year': 1,
    'Within past 2 year': 2,
    'Within past 3 year': 3,
    '5 or more years ago': 5,
    'never': 0
}

columns_to_update = ['checkup1', 'cholchk']

# Fill null values with 0 before applying replacement_mapping
df[columns_to_update] = df[columns_to_update].fillna(0).replace(replacement_mapping)

# %%
"""Using Mean to fill columns"""

# # Define the list of columns to be converted to numeric
columns_to_fill = [				'genhlth'
		,'physhlth'
		,'menthlth'
		,'poorhlth'
		,'checkup1'
		,'sleptim1'
		,'cholchk'
		,'children'
		,'weight2'
		,'height3'
		,'cpdemo4'
		,'alcday5'
		,'fruitju1'
		,'fruit1'
		,'fvbeans'
		,'fvgreen'
		,'fvorang'
		,'vegetab1'
		,'exeroft1'
		,'exerhmm1'
		,'hlthcvrg'
		,'drvisits'
		,'X_strwt'
		,'X_rawrake'
		,'X_wt2rake'
		,'X_llcpwt2'
		,'X_llcpwt'
		,'htin4'
		,'htm4'
		,'wtkg3'
		,'X_bmi5'
		,'ftjuda1_'
		,'frutda1_'
		,'beanday_'
		,'grenday_'
		,'orngday_'
		,'vegeda1_'
		,'X_frutsum'
		,'X_vegesum'
		,'metvl11_'
		,'metvl21_'
		,'maxvo2_'
		,'fc60_'
		,'padur1_'
		,'pafreq1_'
		,'X_minac11'
		,'X_minac21'
		,'strfreq_'
		,'pamiss1_'
		,'pamin11_'
		,'pamin21_'
		,'pa1min_'
		,'pavig11_'
		,'pavig21_'
		,'pa1vigm_'
        , 'X_impnph']

# # Convert the specified columns to numeric
df[columns_to_fill] = df[columns_to_fill].apply(pd.to_numeric, errors='coerce')
# Calculate the mean of each column
column_means = df[columns_to_fill].mean()

# Fill NaN values in the specified columns with the mean of each respective column
df[columns_to_fill] = df[columns_to_fill].fillna(column_means)

# %%
columns_to_update = ['hlthpln1', 'persdoc2', 'medcost', 'bloodcho', 'cvdinfr4', 'cvdcrhd4', 'cvdstrk3', 'asthma3', 'chcscncr', 'chcocncr', 'chccopd1', 'havarth3', 'addepev2', 'chckidny', 'diabete3', 'veteran3', 'qlactlm2', 'useequip', 'blind', 'decide', 'diffwalk', 'diffdres', 'diffalon','hlthpln1']

# Update missing values to 'No' in the specified columns for rows where 'X_age80' is less than 30
df.loc[df['X_age80'] < 30, columns_to_update].fillna('No')

# Define the columns to update and their corresponding values
update_values = {
    'marital': 'Never married',
    'employ1': 'Out of work',
    'renthom1': 'Rent'
}

# %%
# Update the missing values in the specified columns where 'X_age80' is less than 30
for column, value in update_values.items():
    df.loc[df['X_age80'] < 30, column] = df.loc[df['X_age80'] < 30, column].fillna(value)

columns_to_update_unknown = [
    'seatbelt', 'flushot6', 'tetanus', 'pneuvac3', 'hivtst6',
    'X_prace1', 'X_mrace1', 'X_hispanc', 'X_race', 'X_raceg21', 'X_racegr3',
    'X_race_g1', 'X_ageg5yr', 'X_age65yr', 'X_age_g', 'X_chldcnt', 'X_educag',
    'X_misfrtn', 'X_misvegn', 'X_frtresp', 'X_vegresp', 'X_pacat1', 'X_paindx1',
    'X_pa150r2', 'X_pa300r2', 'X_pa30021', 'X_pastrng', 'X_parec1', 'X_pastae1',
    'X_lmtact1', 'X_lmtwrk1', 'X_lmtscl1', 'X_rfseat2', 'bphigh4', 'marital',
    'educa', 'income2', 'renthom1', 'genhlth', 'persdoc2', 'medcost', 'bloodcho',
    'cvdinfr4', 'cvdcrhd4', 'cvdstrk3'
]

for column in columns_to_update_unknown:
    df[column] = df[column].fillna('unknown')

# %%
import numpy as np

df['asthnow'] = np.where(df['asthma3'] == 'No', 'No', 'Yes')

# Update 'bpmeds' column based on 'bphigh4' condition
df.loc[df['bphigh4'] == 'No', 'bpmeds'] = 'No'
df.loc[df['bphigh4'] != 'No', 'bpmeds'] = 'Yes'

# %%
# Update 'asthnow' column based on 'asthma3' condition
df.loc[df['asthma3'] == 'No', 'asthnow'] = 'No'
df.loc[df['asthma3'] != 'No', 'asthnow'] = 'Yes'

# %%
# Update "toldhi2" column based on "bloodcho"
df['toldhi2'] = np.where(df['bloodcho'] == 'No', 'Yes', 'No')

# %%
# Update 'employ1' column to 'Out of Work' where data has missing values
df.loc[df['employ1'].isnull(), 'employ1'] = 'Out of Work'

# %%
# Update "internet" column to 'Yes' where data points are missing
df['internet'].fillna('Yes', inplace=True)

# %%
# Update "renthom1" column to 'Rent' where data points are missing
df['renthom1'].fillna('Rent', inplace=True)

# %%
missing_values = df.isnull().sum()
print("Missing Values Count for Each Column:")
pd.set_option('display.max_rows', None)  # Display all rows
print(missing_values)
pd.reset_option('display.max_rows')  # Reset row display options
# Out:
# Missing Values Count for Each Column:
# Unnamed: 0         0
# X_state            0
# fmonth             3
# idate              2
# imonth             3
# iday               3
# iyear              5
# dispcode           5
# seqno              3
# X_psu              2
# genhlth            0
# physhlth           0
# menthlth           0
# poorhlth           0
# hlthpln1        1904
# persdoc2           0
# medcost            0
# checkup1           0
# sleptim1           0
# bphigh4            0
# bloodcho           0
# cholchk            0
# toldhi2            0
# cvdinfr4           0
# cvdcrhd4           0
# cvdstrk3           0
# asthma3         1559
# chcscncr        1309
# chcocncr        1148
# chccopd1        2724
# havarth3        2970
# addepev2        2289
# chckidny        1721
# diabete3         832
# veteran3         746
# marital            0
# children           0
# educa              0
# employ1            0
# income2            0
# weight2            0
# height3            0
# cpdemo4            0
# internet           0
# renthom1           0
# sex                7
# qlactlm2       11329
# useequip       10317
# blind          11079
# decide         12990
# diffwalk       12764
# diffdres       12122
# diffalon       13350
# smoke100       14920
# usenow3        14018
# alcday5            0
# fruitju1           0
# fruit1             0
# fvbeans            0
# fvgreen            0
# fvorang            0
# vegetab1           0
# exeroft1           0
# exerhmm1           0
# strength       39819
# seatbelt           0
# flushot6           0
# tetanus            0
# pneuvac3           0
# hivtst6            0
# medicare      178791
# hlthcvrg           0
# delaymed      144721
# nocov121      182112
# drvisits           0
# medscost      142625
# carercvd      153216
# medbills      144297
# X_ststr            4
# X_strwt            0
# X_rawrake          0
# X_wt2rake          0
# X_impnph           0
# X_dualuse         11
# X_llcpwt2          0
# X_llcpwt           0
# X_rfhlth        1989
# X_rfhype5       1427
# X_cholchk      14286
# X_rfchol       71664
# X_ltasth1       1567
# X_casthm1       3430
# X_asthms1       3429
# X_drdxar1       2976
# X_prace1           0
# X_mrace1           0
# X_hispanc          0
# X_race             0
# X_raceg21          0
# X_racegr3          0
# X_race_g1          0
# X_ageg5yr          0
# X_age65yr          0
# X_age_g            0
# htin4              0
# htm4               0
# wtkg3              0
# X_bmi5             0
# X_bmi5cat      26727
# X_rfbmi5       26729
# X_chldcnt          0
# X_educag           0
# X_incomg       71428
# X_smoker3      15333
# X_rfsmok3      15335
# drnkany5       19647
# drocdy3_       19646
# X_rfbing5      23731
# X_drnkdy4      23881
# X_drnkmo4      23882
# X_rfdrhv4      23883
# X_rfdrwm4     214307
# ftjuda1_           0
# frutda1_           0
# beanday_           0
# grenday_           0
# orngday_           0
# vegeda1_           0
# X_misfrtn          0
# X_misvegn          0
# X_frtresp          0
# X_vegresp          0
# X_frutsum          0
# X_vegesum          0
# X_frtlt1       28703
# X_veglt1       30164
# X_frt16           10
# X_veg23           12
# X_fruitex         10
# X_vegetex         12
# X_totinda      34034
# metvl11_           0
# metvl21_           0
# maxvo2_            0
# fc60_              0
# actin11_      177754
# actin21_      186563
# padur1_            0
# pafreq1_           0
# X_minac11          0
# X_minac21          0
# strfreq_           0
# pamiss1_           0
# pamin11_           0
# pamin21_           0
# pa1min_            0
# pavig11_           0
# pavig21_           0
# pa1vigm_           0
# X_pacat1           0
# X_paindx1          0
# X_pa150r2          0
# X_pa300r2          0
# X_pa30021          0
# X_pastrng          0
# X_parec1           0
# X_pastae1          0
# X_lmtact1          0
# X_lmtwrk1          0
# X_lmtscl1          0
# X_rfseat2          0
# X_rfseat3      38941
# X_aidtst3      54595
# X_age80           11
# asthnow            0
# bpmeds             0
# dtype: int64

# %%
# Filter and get the list of numerical columns
numerical_columns = df.select_dtypes(include=[float, int]).columns.tolist()

# Replace missing values in numerical columns with their mean
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# Replace missing values in categorical columns with their mode
categorical_columns = df.select_dtypes(include=[object]).columns.tolist()
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
from scipy.stats import zscore

# 'df' is the DataFrame with numerical columns
numerical_columns = df.select_dtypes(include=[float, int]).columns.tolist()

# Calculating z-scores for each numerical column
z_scores = np.abs(zscore(df[numerical_columns]))

# Defining a threshold for identifying outliers (e.g., z_score_threshold = 3)
z_score_threshold = 3

# Find and remove rows containing outliers
outlier_rows = np.any(z_scores > z_score_threshold, axis=1)
df_no_outliers = df[~outlier_rows]

# Print the number of rows before and after handling outliers
print(f"Number of rows before handling outliers: {len(df)}")
print(f"Number of rows after handling outliers: {len(df_no_outliers)}")
# Out:
# Number of rows before handling outliers: 491775
# Number of rows after handling outliers: 319651

# %%
# Save the preprocessed DataFrame to a new CSV file
#df.to_csv('preprocessed_dataset.csv', index=False)

# %%
df.shape
# Out:
# (491775, 176)

# %%
missing_values = df.isnull().sum()
print("Missing Values Count for Each Column:")
pd.set_option('display.max_rows', None)  # Display all rows
print(missing_values)
pd.reset_option('display.max_rows')  # Reset row display options
# Out:
# Missing Values Count for Each Column:
# Unnamed: 0    0
# X_state       0
# fmonth        0
# idate         0
# imonth        0
# iday          0
# iyear         0
# dispcode      0
# seqno         0
# X_psu         0
# genhlth       0
# physhlth      0
# menthlth      0
# poorhlth      0
# hlthpln1      0
# persdoc2      0
# medcost       0
# checkup1      0
# sleptim1      0
# bphigh4       0
# bloodcho      0
# cholchk       0
# toldhi2       0
# cvdinfr4      0
# cvdcrhd4      0
# cvdstrk3      0
# asthma3       0
# chcscncr      0
# chcocncr      0
# chccopd1      0
# havarth3      0
# addepev2      0
# chckidny      0
# diabete3      0
# veteran3      0
# marital       0
# children      0
# educa         0
# employ1       0
# income2       0
# weight2       0
# height3       0
# cpdemo4       0
# internet      0
# renthom1      0
# sex           0
# qlactlm2      0
# useequip      0
# blind         0
# decide        0
# diffwalk      0
# diffdres      0
# diffalon      0
# smoke100      0
# usenow3       0
# alcday5       0
# fruitju1      0
# fruit1        0
# fvbeans       0
# fvgreen       0
# fvorang       0
# vegetab1      0
# exeroft1      0
# exerhmm1      0
# strength      0
# seatbelt      0
# flushot6      0
# tetanus       0
# pneuvac3      0
# hivtst6       0
# medicare      0
# hlthcvrg      0
# delaymed      0
# nocov121      0
# drvisits      0
# medscost      0
# carercvd      0
# medbills      0
# X_ststr       0
# X_strwt       0
# X_rawrake     0
# X_wt2rake     0
# X_impnph      0
# X_dualuse     0
# X_llcpwt2     0
# X_llcpwt      0
# X_rfhlth      0
# X_rfhype5     0
# X_cholchk     0
# X_rfchol      0
# X_ltasth1     0
# X_casthm1     0
# X_asthms1     0
# X_drdxar1     0
# X_prace1      0
# X_mrace1      0
# X_hispanc     0
# X_race        0
# X_raceg21     0
# X_racegr3     0
# X_race_g1     0
# X_ageg5yr     0
# X_age65yr     0
# X_age_g       0
# htin4         0
# htm4          0
# wtkg3         0
# X_bmi5        0
# X_bmi5cat     0
# X_rfbmi5      0
# X_chldcnt     0
# X_educag      0
# X_incomg      0
# X_smoker3     0
# X_rfsmok3     0
# drnkany5      0
# drocdy3_      0
# X_rfbing5     0
# X_drnkdy4     0
# X_drnkmo4     0
# X_rfdrhv4     0
# X_rfdrwm4     0
# ftjuda1_      0
# frutda1_      0
# beanday_      0
# grenday_      0
# orngday_      0
# vegeda1_      0
# X_misfrtn     0
# X_misvegn     0
# X_frtresp     0
# X_vegresp     0
# X_frutsum     0
# X_vegesum     0
# X_frtlt1      0
# X_veglt1      0
# X_frt16       0
# X_veg23       0
# X_fruitex     0
# X_vegetex     0
# X_totinda     0
# metvl11_      0
# metvl21_      0
# maxvo2_       0
# fc60_         0
# actin11_      0
# actin21_      0
# padur1_       0
# pafreq1_      0
# X_minac11     0
# X_minac21     0
# strfreq_      0
# pamiss1_      0
# pamin11_      0
# pamin21_      0
# pa1min_       0
# pavig11_      0
# pavig21_      0
# pa1vigm_      0
# X_pacat1      0
# X_paindx1     0
# X_pa150r2     0
# X_pa300r2     0
# X_pa30021     0
# X_pastrng     0
# X_parec1      0
# X_pastae1     0
# X_lmtact1     0
# X_lmtwrk1     0
# X_lmtscl1     0
# X_rfseat2     0
# X_rfseat3     0
# X_aidtst3     0
# X_age80       0
# asthnow       0
# bpmeds        0
# dtype: int64

# %%
#Feature Engg for Depression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Define features and target variable
target_variable = 'addepev2' 
target = df[target_variable]

# Exclude the target variable from features
features = df.columns.difference([target_variable])


# Identify numeric and non-numeric columns
numeric_features = df[features].select_dtypes(include=np.number).columns
non_numeric_features = df[features].select_dtypes(exclude=np.number).columns

# Handle missing values and scaling
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('non_num', 'drop', non_numeric_features)
    ]
)

features_scaled = preprocessor.fit_transform(df[features])


# Feature Ranking using SelectKBest
selector = SelectKBest(score_func=f_classif, k=10)  # Adjust the value of k as needed
features_selected = selector.fit_transform(features_scaled, target)
selected_feature_indices = selector.get_support(indices=True)
selected_features = df[features].columns[selected_feature_indices]
print("Top selected features:", selected_features)

# correlation_with_target = df[selected_features].apply(lambda x: x.corr(df[target]))
# print("Correlation with Target Variable:\n", correlation_with_target)
# Correlation Heatmap
correlation_matrix = correlation_matrix = pd.DataFrame(features_selected, columns=selected_features).corr()
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Feature Combination
df['activity_product'] = df['exeroft1'] * df['exerhmm1']

# Train a RandomForestClassifier to see feature importances
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Display feature importances
feature_importances = pd.Series(model.feature_importances_, index=numeric_features)
feature_importances = feature_importances.sort_values(ascending=False)
print("\nFeature Importances:\n", feature_importances)

# Select top k features based on importance
k = 10  # You can adjust this value
top_k_features = feature_importances.head(k).index
print(f"Top {k} features based on importance:", top_k_features)
# Out:
# Top selected features: Index(['X_age80', 'X_educag', 'X_hispanc', 'X_impnph', 'X_pa300r2',
#        'X_pastrng', 'X_rfhlth', 'X_rfhype5', 'X_rfseat3', 'X_totinda'],
#       dtype='object')
# C:\Users\sachu\AppData\Local\Temp\ipykernel_28112\1837729705.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['activity_product'] = df['exeroft1'] * df['exerhmm1']
# Feature Importances:
#  menthlth    0.124070
# poorhlth    0.050764
# physhlth    0.027473
# X_bmi5      0.024608
# drvisits    0.023681
#               ...
# pavig21_    0.004816
# checkup1    0.004727
# hlthcvrg    0.003320
# pamiss1_    0.002222
# iyear       0.000649
# Length: 66, dtype: float64
# Top 10 features based on importance: Index(['menthlth', 'poorhlth', 'physhlth', 'X_bmi5', 'drvisits', 'idate',
#        'X_llcpwt', 'Unnamed: 0', 'seqno', 'X_psu'],
#       dtype='object')

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt


# Define features and target
features = ['menthlth', 'poorhlth', 'physhlth', 'X_bmi5', 'drvisits', 'X_llcpwt2', 'X_vegesum', 'fc60_', 'maxvo2_', 'X_impnph']
target_variable = 'addepev2' 
target = df[target_variable]
# Identify numeric and non-numeric columns
numeric_features = df[features].select_dtypes(include=np.number).columns
non_numeric_features = df[features].select_dtypes(exclude=np.number).columns
# Handle missing values and scaling
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('non_num', 'drop', non_numeric_features)
    ]
)

# Transform the features
features_scaled = preprocessor.fit_transform(df[features])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)
# Train a RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("\nClassification Report:\n", report)
print("\nConfusion Matrix:\n", conf_matrix)

# Visualize class separability using PCA
pca = PCA(n_components=2)
features_pca = pca.fit_transform(features_scaled)

# Add the target variable to the reduced features for visualization
features_pca_df = pd.DataFrame(features_pca, columns=['PC1', 'PC2'])
features_pca_df['Target'] = target.values

# Visualize class separability using a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x='PC1', y='PC2', hue='Target', data=features_pca_df, palette='viridis')
plt.title('Class Separability - PCA')
plt.show()
# Out:
# Accuracy: 0.8392862589598902
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.86      0.96      0.91     79425
#          Yes       0.65      0.35      0.46     18930
#
#     accuracy                           0.84     98355
#    macro avg       0.76      0.65      0.68     98355
# weighted avg       0.82      0.84      0.82     98355
#
#
# Confusion Matrix:
#  [[75891  3534]
#  [12273  6657]]

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd



features = ['menthlth', 'poorhlth', 'physhlth', 'X_bmi5', 'drvisits', 'X_llcpwt2', 'X_vegesum', 'fc60_', 'maxvo2_', 'X_impnph']
target_variable = 'addepev2' 
target = df[target_variable]

numeric_features = df[features].select_dtypes(include=np.number).columns
non_numeric_features = df[features].select_dtypes(exclude=np.number).columns

# Handle missing values and scaling
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('non_num', 'drop', non_numeric_features)
    ]
)

# Transform the features
features_scaled = preprocessor.fit_transform(df[features])

# Reduce the data for faster testing
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)

# Define the hyperparameter search space
param_dist = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Create the RandomForestClassifier
model = RandomForestClassifier(random_state=42)

# Create the RandomizedSearchCV object with reduced iterations
random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=5, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)

# Fit the model to the data
random_search.fit(X_train, y_train)

# Print the best parameters found
print("Best Parameters:", random_search.best_params_)

# Get the best model
best_model = random_search.best_estimator_

# Make predictions on the test set using the best model
y_pred_tuned = best_model.predict(X_test)

# Evaluate the tuned model
accuracy_tuned = accuracy_score(y_test, y_pred_tuned)
report_tuned = classification_report(y_test, y_pred_tuned)
conf_matrix_tuned = confusion_matrix(y_test, y_pred_tuned)

print(f"\nTuned Model Accuracy: {accuracy_tuned}")
print("\nTuned Model Classification Report:\n", report_tuned)
print("\nTuned Model Confusion Matrix:\n", conf_matrix_tuned)
# Out:
# Best Parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False}
#
# Tuned Model Accuracy: 0.8398352905292055
#
# Tuned Model Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.86      0.96      0.91     79425
#          Yes       0.67      0.33      0.44     18930
#
#     accuracy                           0.84     98355
#    macro avg       0.76      0.64      0.67     98355
# weighted avg       0.82      0.84      0.82     98355
#
#
# Tuned Model Confusion Matrix:
#  [[76394  3031]
#  [12722  6208]]

# %%
print(df[features])
# Out:
#          menthlth   poorhlth  physhlth       X_bmi5   drvisits   X_llcpwt2  \
# 0       29.000000  30.000000      30.0  3916.000000   5.000000  331.493357
# 1        0.000000   5.300882       0.0  1822.000000   3.000000  662.986714
# 2        2.000000   0.000000       3.0  2746.000000   6.000000  994.480071
# 3        0.000000   0.000000       2.0  2197.000000   1.000000  662.986714
# 4        2.000000   0.000000      10.0  3594.000000   2.000000  994.853994
# ...           ...        ...       ...          ...        ...         ...
# 491770  15.000000   0.000000      14.0  2695.000000   3.000000  800.887347
# 491771   0.000000   5.300882       0.0  3224.000000   5.244299  800.887347
# 491772  20.000000   0.000000      15.0  2613.000000  15.000000  800.887347
# 491773   0.000000   5.300882       0.0  2231.000000   0.000000  800.887347
# 491774   3.382734  30.000000      30.0  2782.447803   3.000000    8.000000
#
#         X_vegesum       fc60_      maxvo2_  X_impnph
# 0        53.00000  442.000000  2580.000000  2.000000
# 1       148.00000  506.000000  2950.000000  1.000000
# 2       191.00000  474.000000  2765.000000  1.000000
# 3       136.00000  417.000000  2432.000000  1.000000
# 4       243.00000  406.000000  2370.000000  1.000000
# ...           ...         ...          ...       ...
# 491770  329.00000  455.000000  2654.000000  1.025929
# 491771  100.00000  444.000000  2590.000000  1.025929
# 491772  127.00000  588.000000  3431.000000  1.025929
# 491773  186.00000  633.000000  3690.000000  1.025929
# 491774  190.01065  489.654219  2856.278362  1.025929
#
# [491775 rows x 10 columns]
